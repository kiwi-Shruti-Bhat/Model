# %% [markdown]
# <a href="https://colab.research.google.com/github/kiwi-Shruti-Bhat/Model/blob/main/BMI_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Objective :

# %% [markdown]
# Give a human image , identify height and weight and BMI of the individual.

# %% [markdown]
# ## Solution :

# %% [markdown]
# The solution has been inspired by the paper [FACE2BMI](https://arxiv.org/pdf/1703.03156.pdf). This paper shows that face can be an important estimator of your height and weight and hence the BMI. The dataset quoted in the papaer is not publicly available hence i could not use the mentioned dataset for my work. I gathered data from internet manualyy. I have used almost similar technique in which i have used the celebrity's face to estimate their height,weight and BMI.

# %% [markdown]
# ## Solution workflow
#
#  > Image ==> Face ==>  Face embedding ==> Height
#
#  > Image ==> Face ==>  Face embedding ==> Weight
#
#  > Image ==> Face ==>  Face embedding ==> BMI

# %% [markdown]
# ## Data  Collection and Augmentation

# %% [markdown]
# The dataset consists of 5-20 images of bollywood celeberities. The various images has been taken under different conditions so that we have enough variations.
# The images that has been taken is downloaded using google serach engine results. Care has been taken care that all the images are latest. The label for each celeberity has been noted from the publicly available forums.

# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# %reload_ext google.cloud.bigquery

# %%
label_file = "./BMI data - Sheet1.csv"

# %%
import pandas as pd

# %%
profile_df = pd.read_csv(label_file)

# %%
profile_df
# Out:
#     id       UID              name  height  weight        BMI
# 0    1    akshay      akshay kumar    1.78      80  25.249337
# 1    2        ja      john abraham    1.82      94  28.378215
# 2    3     varun      varun dhawan    1.68      78  27.636054
# 3    4     tiger      Tiger shroff    1.75      72  23.510204
# 4    5    salman       Salman khan    1.74      75  24.772097
# 5    6       srk     Shahrukh khan    1.73      75  25.059307
# 6    7  ayushman  ayushman khurana    1.68      72  25.510204
# 7    8     vikky     vicky kaushal    1.83      80  23.888441
# 8    9  rajkumar      rajkumar rao    1.70      72  24.913495
# 9   10     nawaz        nawazuddin    1.68      60  21.258503
# 10  11     manoj    manoj bajpayee    1.75      68  22.204082
# 11  12    anurag    Anurag kashyap    1.78      84  26.511804
# 12  13    pankaj    Pankaj Tripati    1.75      70  22.857143
# 13  14    kirron       kirron kher    1.65      68  24.977043
# 14  15     richa     richa chadhha    1.65      57  20.936639
# 15  16     kalki     kalki koechin    1.70      53  18.339100
# 16  17   radhika      Radhika apte    1.60      55  21.484375
# 17  18    anupam       anupam kher    1.68      70  24.801587
# 18  19   supriya    supriya pathak    1.63      72  27.099251
# 19  20     ratna      ratna pathak    1.63      55  20.700817
# 20  21      amir         amir khan    1.63      70  26.346494
# 21  22    arshad      arshad warsi    1.68      70  24.801587

# %% [markdown]
# ## How is BMI calculated?
# ```
# BMI = (Weight in Kg) / ((Height in Meters) ^ 2)
# ```

# %% [markdown]
# All the training images are kept in the following directory

# %%
data_folder = "height_weight"

# %%
from glob import glob
all_files = glob(data_folder+"/*")

all_jpgs = sorted([img for img in all_files if ".jpg" in img or ".jpeg" in img or "JPG" in img])

print("Total {} photos ".format(len(all_jpgs)))
# Out:
# Total 194 photos

# %%
from pathlib import Path as p

# %%
def get_index_of_digit(string):
    import re
    match = re.search("\d", p(string).stem)
    return match.start(0)

# %%
id_path = [(p(images).stem[:(get_index_of_digit(p(images).stem))],images) for  images in all_jpgs ]

# %%
image_df = pd.DataFrame(id_path,columns=['UID','path'])

# %%
data_df = image_df.merge(profile_df) ## merged the training images with their profile

# %%
data_df
# Out:
#          UID                        path  id            name  height  weight  \
# 0     akshay  height_weight/akshay1.jpeg   1    akshay kumar    1.78      80
# 1     akshay  height_weight/akshay10.jpg   1    akshay kumar    1.78      80
# 2     akshay  height_weight/akshay11.jpg   1    akshay kumar    1.78      80
# 3     akshay  height_weight/akshay12.jpg   1    akshay kumar    1.78      80
# 4     akshay  height_weight/akshay13.jpg   1    akshay kumar    1.78      80
# ..       ...                         ...  ..             ...     ...     ...
# 189      srk      height_weight/srk9.jpg   6   Shahrukh khan    1.73      75
# 190  supriya  height_weight/supriya1.jpg  19  supriya pathak    1.63      72
# 191  supriya  height_weight/supriya2.jpg  19  supriya pathak    1.63      72
# 192  supriya  height_weight/supriya3.jpg  19  supriya pathak    1.63      72
# 193  supriya  height_weight/supriya4.jpg  19  supriya pathak    1.63      72
#
#            BMI
# 0    25.249337
# 1    25.249337
# 2    25.249337
# 3    25.249337
# 4    25.249337
# ..         ...
# 189  25.059307
# 190  27.099251
# 191  27.099251
# 192  27.099251
# 193  27.099251
#
# [194 rows x 7 columns]

# %% [markdown]
# ## Extract face embedding using facenet pretrained architecture

# %%
# !pip3 install face_recognition
# Out:
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from face_recognition) (8.4.0)
# Requirement already satisfied: Click>=6.0 in /opt/conda/lib/python3.7/site-packages (from face_recognition) (8.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from face_recognition) (1.19.5)
# Collecting dlib>=19.7
#   Using cached dlib-19.22.1.tar.gz (7.4 MB)
#   Preparing metadata (setup.py) ... done
# Collecting face-recognition-models>=0.3.0
#   Using cached face_recognition_models-0.3.0.tar.gz (100.1 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from Click>=6.0->face_recognition) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->Click>=6.0->face_recognition) (4.0.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->Click>=6.0->face_recognition) (3.6.0)
# Building wheels for collected packages: dlib, face-recognition-models
#   Building wheel for dlib (setup.py) ... done
#   Created wheel for dlib: filename=dlib-19.22.1-cp37-cp37m-linux_x86_64.whl size=3670179 sha256=b976055213f0f19447bc0c0b093c1d5e3d00251b18937eeb733d4723bc599b41
#   Stored in directory: /home/jupyter/.cache/pip/wheels/10/6f/db/ef0380a66d955f9caa81cff6027fb77c0b556568e0daace292
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=d2934961dc097b8e8c7e9e7be58096267248d057b5d91d7328208b341817ae17
#   Stored in directory: /home/jupyter/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built dlib face-recognition-models
# Installing collected packages: face-recognition-models, dlib, face-recognition
# Successfully installed dlib-19.22.1 face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
import face_recognition
import numpy as np

# %%
def get_face_encoding(image_path):
    print(image_path)
    picture_of_me = face_recognition.load_image_file(image_path)
    my_face_encoding = face_recognition.face_encodings(picture_of_me)
    if not my_face_encoding:
        pass
        return np.zeros(128).tolist()
    return my_face_encoding[0].tolist()

# %%
def get_face_test(url) :
    response = urllib.request.urlopen(url)
    picture_of_me = face_recognition.load_image_file(response)
    my_face_encoding = face_recognition.face_encodings(picture_of_me)
    if not my_face_encoding:
        print("no face found !!!")
        return np.zeros(128).tolist()
    return my_face_encoding[0].tolist()

# %%
all_faces = []

# %%
for images in data_df.path:
    face_enc = get_face_encoding(images)
    all_faces.append(face_enc)
# Out:
# height_weight/akshay1.jpeg
# height_weight/akshay10.jpg
# height_weight/akshay11.jpg
# height_weight/akshay12.jpg
# height_weight/akshay13.jpg
# height_weight/akshay14.jpg
# height_weight/akshay15.jpg
# height_weight/akshay16.jpg
# height_weight/akshay17.jpg
# height_weight/akshay18.jpg
# height_weight/akshay19.jpg
# height_weight/akshay2.jpeg
# no face found !!!
# height_weight/akshay20.jpg
# height_weight/akshay3.jpg
# height_weight/akshay4.jpg
# height_weight/akshay5.jpg
# height_weight/akshay6.jpg
# height_weight/akshay7.jpg
# height_weight/akshay8.jpg
# height_weight/akshay9.jpg
# height_weight/amir1.jpg
# height_weight/amir10.jpg
# height_weight/amir11.jpg
# height_weight/amir12.jpg
# height_weight/amir13.jpg
# height_weight/amir14.jpeg
# height_weight/amir15.jpg
# height_weight/amir2.jpg
# height_weight/amir3.jpg
# height_weight/amir4.jpeg
# no face found !!!
# height_weight/amir5.jpg
# height_weight/amir7.jpeg
# height_weight/amir8.jpg
# height_weight/amir9.jpg
# height_weight/anupam2.jpg
# height_weight/anupam3.jpg
# height_weight/anupam4.jpg
# height_weight/anupam5.jpg
# height_weight/anupam6.jpg
# height_weight/anupam7.jpeg
# height_weight/anupam8.jpg
# height_weight/anurag1.jpg
# height_weight/anurag2.jpg
# height_weight/anurag3.jpg
# height_weight/anurag4.jpg
# height_weight/anurag5.jpg
# height_weight/arshad1.jpg
# height_weight/arshad10.jpg
# height_weight/arshad11.jpg
# height_weight/arshad12.jpeg
# height_weight/arshad13.jpg
# height_weight/arshad14.jpg
# height_weight/arshad15.jpg
# height_weight/arshad16.jpg
# height_weight/arshad2.jpg
# height_weight/arshad3.jpeg
# height_weight/arshad4.jpg
# height_weight/arshad5.jpg
# height_weight/arshad6.jpg
# height_weight/arshad7.jpeg
# height_weight/arshad8.jpeg
# height_weight/arshad9.jpg
# height_weight/ayushman1.jpg
# height_weight/ayushman2.jpeg
# height_weight/ayushman3.JPG
# height_weight/ayushman4.jpg
# height_weight/ayushman5.jpg
# height_weight/ja1.jpg
# height_weight/ja10.jpg
# height_weight/ja11.jpg
# height_weight/ja12.jpg
# height_weight/ja13.jpeg
# height_weight/ja14.jpg
# height_weight/ja15.jpg
# height_weight/ja2.jpg
# height_weight/ja3.jpg
# height_weight/ja4.jpg
# height_weight/ja5.jpg
# height_weight/ja6.jpg
# height_weight/ja7.jpg
# height_weight/ja8.jpg
# height_weight/ja9.jpg
# height_weight/kalki1.jpg
# height_weight/kalki10.jpg
# height_weight/kalki11.jpg
# height_weight/kalki12.jpg
# height_weight/kalki13.jpeg
# height_weight/kalki14.jpg
# height_weight/kalki15.jpg
# height_weight/kalki2.jpg
# height_weight/kalki3.jpeg
# height_weight/kalki4.jpg
# height_weight/kalki5.jpg
# height_weight/kalki6.jpg
# height_weight/kalki7.jpg
# height_weight/kalki8.jpg
# height_weight/kalki9.jpg
# height_weight/kirron1.jpg
# height_weight/kirron10.jpg
# height_weight/kirron2.jpg
# height_weight/kirron3.jpg
# height_weight/kirron4.jpg
# height_weight/kirron5.jpg
# height_weight/kirron6.jpg
# height_weight/kirron7.jpg
# height_weight/kirron8.jpg
# height_weight/kirron9.jpeg
# height_weight/manoj1.jpg
# height_weight/manoj2.jpeg
# height_weight/manoj3.jpg
# height_weight/manoj4.jpg
# height_weight/manoj5.JPG
# height_weight/nawaz1.jpg
# height_weight/nawaz2.jpg
# height_weight/nawaz3.jpg
# height_weight/nawaz4.jpg
# height_weight/pankaj1.jpg
# height_weight/pankaj2.jpg
# height_weight/pankaj3.jpg
# height_weight/pankaj5.jpg
# height_weight/pankaj6.jpg
# height_weight/radhika1.jpg
# height_weight/radhika10.jpg
# height_weight/radhika11.jpg
# height_weight/radhika12.jpg
# height_weight/radhika13.jpg
# height_weight/radhika14.jpg
# height_weight/radhika15.jpg
# height_weight/radhika2.jpeg
# height_weight/radhika3.jpg
# height_weight/radhika4.jpg
# height_weight/radhika5.jpg
# height_weight/radhika6.jpg
# height_weight/radhika7.jpg
# height_weight/radhika8.jpg
# height_weight/radhika9.jpg
# height_weight/rajkumar1.jpg
# height_weight/rajkumar2.jpg
# height_weight/rajkumar3.jpg
# height_weight/rajkumar4.jpg
# height_weight/rajkumar5.jpg
# height_weight/ratna1.jpeg
# height_weight/ratna2.jpg
# height_weight/ratna3.jpg
# height_weight/ratna4.JPG
# height_weight/ratna5.jpg
# height_weight/ratna6.jpg
# height_weight/richa2.jpg
# height_weight/richa3.JPG
# height_weight/richa4.jpg
# height_weight/richa5.jpg
# height_weight/salman1.jpg
# height_weight/salman10.jpg
# height_weight/salman11.jpg
# height_weight/salman12.jpg
# height_weight/salman13.jpg
# height_weight/salman14.jpg
# height_weight/salman15.jpg
# height_weight/salman16.jpg
# height_weight/salman17.jpg
# height_weight/salman18.jpg
# height_weight/salman19.jpg
# height_weight/salman2.jpg
# height_weight/salman20.jpg
# height_weight/salman3.jpg
# height_weight/salman4.jpg
# height_weight/salman5.jpeg
# height_weight/salman6.jpg
# height_weight/salman7.jpg
# height_weight/salman8.jpg
# height_weight/salman9.jpg
# height_weight/srk1.jpg
# height_weight/srk10.jpeg
# height_weight/srk11.jpg
# height_weight/srk12.jpg
# height_weight/srk13.jpg
# height_weight/srk14.jpg
# height_weight/srk15.jpg
# height_weight/srk16.jpg
# height_weight/srk17.jpg
# height_weight/srk18.jpg
# height_weight/srk19.jpg
# height_weight/srk2.jpg
# height_weight/srk3.jpeg
# no face found !!!
# height_weight/srk4.jpg
# height_weight/srk5.jpg
# height_weight/srk6.jpg
# height_weight/srk7.jpg
# height_weight/srk8.jpg
# height_weight/srk9.jpg
# height_weight/supriya1.jpg
# height_weight/supriya2.jpg
# height_weight/supriya3.jpg
# height_weight/supriya4.jpg

# %%
X = np.array(all_faces) ## This is the training data matrix

# %%
y_height = data_df.height.values ## all labels
y_weight = data_df.weight.values
y_BMI = data_df.BMI.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_height_train, y_height_test, y_weight_train, y_weight_test ,y_BMI_train, y_BMI_test = train_test_split(X, y_height,y_weight,y_BMI, random_state=1)

# %% [markdown]
# ## Metric to check the goodness of fit

# %%
def report_goodness(model,X_test,y_test,predictor_log=True):
    # Make predictions using the testing set
    y_pred = model.predict(X_test)
    y_true = y_test
    if predictor_log:
        y_true = np.log(y_test)
    # The coefficients
    # The mean squared error
    print("Mean squared error: %.2f"      % mean_squared_error(y_true, y_pred))
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(y_true, y_pred))
    
    errors = abs(y_pred - y_true)
    mape = 100 * np.mean(errors / y_true)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))

# %% [markdown]
# ## Model selection

# %%
from sklearn.kernel_ridge import KernelRidge
from sklearn import  linear_model
from sklearn.svm import SVR
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Kernel Ridge

# %% [markdown]
# ## Height

# %%
model_height = KernelRidge(kernel='rbf', gamma=0.21,alpha=0.0017)

# %%
model_height = model_height.fit(X_train,np.log(y_height_train))

report_goodness(model_height,X_test,y_height_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.78
# Model Performance
# Average Error: 0.0126 degrees.
# Accuracy = 97.60%.

# %% [markdown]
# ## Weight

# %%
model_weight = KernelRidge(kernel='rbf', gamma=0.21,alpha=0.0017)

# %%
model_weight = model_weight.fit(X_train,np.log(y_weight_train))

report_goodness(model_weight,X_test,y_weight_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.84
# Model Performance
# Average Error: 0.0439 degrees.
# Accuracy = 98.96%.

# %% [markdown]
# ## BMI

# %%
model_BMI = KernelRidge(kernel='rbf', gamma=0.21,alpha=0.0017)

# %%
model_BMI = model_BMI.fit(X_train,np.log(y_BMI_train))

report_goodness(model_BMI,X_test,y_BMI_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.82
# Model Performance
# Average Error: 0.0310 degrees.
# Accuracy = 99.02%.

# %%
report_goodness(model_BMI,X_test,y_BMI_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.82
# Model Performance
# Average Error: 0.0310 degrees.
# Accuracy = 99.02%.

# %% [markdown]
# ## Conclusion :

# %% [markdown]
# We found that kernelised Ridge regression outperformed all the models in terms of the mean squared error and expalined variance

# %% [markdown]
# ## save all models

# %%
import joblib

# %% [markdown]
# # save the model to disk

# %%
height_model = 'weight_predictor.model'
weight_model = 'height_predictor.model'
bmi_model = 'bmi_predictor.model'
joblib.dump(model_height, height_model)
joblib.dump(model_weight, weight_model)
joblib.dump(model_BMI, bmi_model)
# Out:
# ['bmi_predictor.model']

# %% [markdown]
# # load the model from disk

# %%
height_model = joblib.load(height_model)
weight_model = joblib.load(weight_model)
bmi_model = joblib.load(bmi_model)

# %% [markdown]
# ## test

# %%
def predict_height_width_BMI(test_image,height_model,weight_model,bmi_model):
    test_array = np.expand_dims(np.array(get_face_test(test_image)),axis=0)
    height = np.exp(height_model.predict(test_array)).item()
    weight = np.exp(weight_model.predict(test_array)).item()
    bmi = np.exp(bmi_model.predict(test_array)).item()
    return {'height':height,'weight':weight,'bmi':bmi}

# %% [markdown]
# ## prediction on test images

# %%
from IPython.display import Image
from PIL import Image
import requests
from io import BytesIO

import urllib.request

# %%
from google.cloud import bigquery

bqclient = bigquery.Client()

query_string = """
SELECT
    *,
FROM `columbia-obesity.image_links.sample_images`
"""
image_links = (
    bqclient.query(query_string)
    .result()
    .to_dataframe(
        # Optionally, explicitly request to use the BigQuery Storage API. As of
        # google-cloud-bigquery version 1.26.0 and above, the BigQuery Storage
        # API is used by default.
        create_bqstorage_client=True,
    )
)

# %%
image_links
# Out:
#                         name       lat       lng  \
# 0           Ashton, Maryland  39.15356 -77.00375
# 1           Ashton, Maryland  39.15356 -77.00375
# 2           Ashton, Maryland  39.15356 -77.00375
# 3           Ashton, Maryland  39.15356 -77.00375
# 4           Ashton, Maryland  39.15356 -77.00375
# ...                      ...       ...       ...
# 12624  Huffman Hills MX Park       NaN       NaN
# 12625  Huffman Hills MX Park       NaN       NaN
# 12626  Huffman Hills MX Park       NaN       NaN
# 12627  Huffman Hills MX Park       NaN       NaN
# 12628  Huffman Hills MX Park       NaN       NaN
#
#                                                    links      external_id  \
# 0      https://scontent-lga3-2.cdninstagram.com/v/t51...  112777142067835
# 1      https://scontent-lga3-2.cdninstagram.com/v/t51...  112777142067835
# 2      https://scontent-lga3-2.cdninstagram.com/v/t51...  112777142067835
# 3      https://scontent-lga3-2.cdninstagram.com/v/t51...  112777142067835
# 4      https://scontent-lga3-2.cdninstagram.com/v/t51...  112777142067835
# ...                                                  ...              ...
# 12624  https://scontent-lga3-2.cdninstagram.com/v/t51...  837344533101834
# 12625  https://scontent-lga3-2.cdninstagram.com/v/t51...  837344533101834
# 12626  https://scontent-lga3-2.cdninstagram.com/v/t51...  837344533101834
# 12627  https://scontent-lga3-2.cdninstagram.com/v/t51...  837344533101834
# 12628  https://scontent-lga3-2.cdninstagram.com/v/t51...  837344533101834
#
#           state
# 0      Maryland
# 1      Maryland
# 2      Maryland
# 3      Maryland
# 4      Maryland
# ...         ...
# 12624      Ohio
# 12625      Ohio
# 12626      Ohio
# 12627      Ohio
# 12628      Ohio
#
# [12629 rows x 6 columns]

# %%
begin_time = datetime.datetime.now()
bmi_final = pd.DataFrame(columns = ['height','weight','bmi'])
c = 0
for i in image_links['links'] :
    print(c)
    c = c+1
    url = i
    a = pd.DataFrame(list(predict_height_width_BMI(url,height_model,weight_model,bmi_model).items())).transpose()
    a.rename(columns={0:'height',1:'weight',2:'bmi'},inplace=True)
    a = a[1:]
    a['url'] = url
    bmi_final = bmi_final.append(a)
bmi_final
# Out:
# 0
# no face found !!!
# 1
# 2
# 3
# 4
# no face found !!!
# 5
# no face found !!!
# 6
# no face found !!!
# 7
# no face found !!!
# 8
# no face found !!!
# 9
# 10
# 11
# no face found !!!
# 12
# no face found !!!
# 13
# no face found !!!
# 14
# no face found !!!
# 15
# 16
# no face found !!!
# 17
# 18
# no face found !!!
# 19
# 20
# no face found !!!
# 21
# 22
# no face found !!!
# 23
# 24
# no face found !!!
# 25
# no face found !!!
# 26
# 27
# 28
# no face found !!!
# 29
# 30
# no face found !!!
# 31
# no face found !!!
# 32
# no face found !!!
# 33
# no face found !!!
# 34
# 35
# no face found !!!
# 36
# no face found !!!
# 37
# 38
# no face found !!!
# 39
# no face found !!!
# 40
# 41
# no face found !!!
# 42
# 43
# 44
# 45
# no face found !!!
# 46
# 47
# no face found !!!
# 48
# 49
# 50
# 51
# no face found !!!
# 52
# 53
# no face found !!!
# 54
# 55
# no face found !!!
# 56
# 57
# 58
# 59
# 60
# no face found !!!
# 61
# 62
# no face found !!!
# 63
# no face found !!!
# 64
# 65
# no face found !!!
# 66
# no face found !!!
# 67
# no face found !!!
# 68
# no face found !!!
# 69
# no face found !!!
# 70
# 71
# 72
# no face found !!!
# 73
# no face found !!!
# 74
# no face found !!!
# 75
# no face found !!!
# 76
# no face found !!!
# 77
# 78
# 79
# no face found !!!
# 80
# no face found !!!
# 81
# 82
# 83
# 84
# 85
# no face found !!!
# 86
# 87
# no face found !!!
# 88
# 89
# 90
# 91
# no face found !!!
# 92
# no face found !!!
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# no face found !!!
# 103
# no face found !!!
# 104
# 105
# 106
# 107
# no face found !!!
# 108
# 109
# no face found !!!
# 110
# 111
# no face found !!!
# 112
# no face found !!!
# 113
# no face found !!!
# 114
# no face found !!!
# 115
# 116
# 117
# 118
# 119
# no face found !!!
# 120
# no face found !!!
# 121
# 122
# no face found !!!
# 123
# no face found !!!
# 124
# no face found !!!
# 125
# no face found !!!
# 126
# no face found !!!
# 127
# 128
# no face found !!!
# 129
# no face found !!!
# 130
# 131
# 132
# no face found !!!
# 133
# 134
# 135
# 136
# no face found !!!
# 137
# 138
# 139
# no face found !!!
# 140
# no face found !!!
# 141
# no face found !!!
# 142
# no face found !!!
# 143
# 144
# no face found !!!
# 145
# no face found !!!
# 146
# no face found !!!
# 147
# no face found !!!
# 148
# 149
# 150
# no face found !!!
# 151
# 152
# no face found !!!
# 153
# no face found !!!
# 154
# 155
# no face found !!!
# 156
# no face found !!!
# 157
# no face found !!!
# 158
# no face found !!!
# 159
# 160
# no face found !!!
# 161
# 162
# 163
# 164
# no face found !!!
# 165
# 166
# 167
# no face found !!!
# 168
# no face found !!!
# 169
# 170
# no face found !!!
# 171
# no face found !!!
# 172
# 173
# no face found !!!
# 174
# no face found !!!
# 175
# no face found !!!
# 176
# no face found !!!
# 177
# 178
# 179
# 180
# no face found !!!
# 181
# no face found !!!
# 182
# 183
# no face found !!!
# 184
# 185
# no face found !!!
# 186
# 187
# 188
# 189
# no face found !!!
# 190
# no face found !!!
# 191
# 192
# 193
# 194
# no face found !!!
# 195
# 196
# no face found !!!
# 197
# no face found !!!
# 198
# no face found !!!
# 199
# no face found !!!
# 200
# no face found !!!
# 201
# no face found !!!
# 202
# no face found !!!
# 203
# no face found !!!
# 204
# no face found !!!
# 205
# no face found !!!
# 206
# 207
# 208
# no face found !!!
# 209
# no face found !!!
# 210
# 211
# 212
# no face found !!!
# 213
# no face found !!!
# 214
# 215
# no face found !!!
# 216
# no face found !!!
# 217
# no face found !!!
# 218
# no face found !!!
# 219
# no face found !!!
# 220
# no face found !!!
# 221
# no face found !!!
# 222
# 223
# 224
# 225
# no face found !!!
# 226
# 227
# no face found !!!
# 228
# 229
# no face found !!!
# 230
# no face found !!!
# 231
# no face found !!!
# 232
# 233
# 234
# 235
# no face found !!!
# 236
# 237
# no face found !!!
# 238
# 239
# 240
# no face found !!!
# 241
# 242
# no face found !!!
# 243
# 244
# no face found !!!
# 245
# no face found !!!
# 246
# 247
# no face found !!!
# 248
# 249
# 250
# 251
# no face found !!!
# 252
# no face found !!!
# 253
# 254
# 255
# no face found !!!
# 256
# no face found !!!
# 257
# no face found !!!
# 258
# 259
# no face found !!!
# 260
# no face found !!!
# 261
# no face found !!!
# 262
# 263
# 264
# no face found !!!
# 265
# no face found !!!
# 266
# no face found !!!
# 267
# 268
# no face found !!!
# 269
# 270
# no face found !!!
# 271
# no face found !!!
# 272
# 273
# no face found !!!
# 274
# 275
# no face found !!!
# 276
# 277
# 278
# 279
# no face found !!!
# 280
# 281
# 282
# 283
# no face found !!!
# 284
# 285
# 286
# 287
# 288
# 289
# no face found !!!
# 290
# 291
# 292
# 293
# 294
# 295
# no face found !!!
# 296
# 297
# 298
# 299
# 300
# no face found !!!
# 301
# 302
# 303
# no face found !!!
# 304
# 305
# no face found !!!
# 306
# no face found !!!
# 307
# no face found !!!
# 308
# 309
# 310
# 311
# 312
# no face found !!!
# 313
# 314
# 315
# no face found !!!
# 316
# 317
# 318
# 319
# no face found !!!
# 320
# 321
# no face found !!!
# 322
# 323
# no face found !!!
# 324
# no face found !!!
# 325
# no face found !!!
# 326
# no face found !!!
# 327
# no face found !!!
# 328
# no face found !!!
# 329
# no face found !!!
# 330
# no face found !!!
# 331
# 332
# 333
# 334
# 335
# no face found !!!
# 336
# 337
# 338
# 339
# no face found !!!
# 340
# 341
# 342
# no face found !!!
# 343
# no face found !!!
# 344
# 345
# 346
# no face found !!!
# 347
# 348
# no face found !!!
# 349
# no face found !!!
# 350
# 351
# no face found !!!
# 352
# 353
# 354
# 355
# 356
# no face found !!!
# 357
# no face found !!!
# 358
# 359
# no face found !!!
# 360
# no face found !!!
# 361
# 362
# 363
# no face found !!!
# 364
# 365
# 366
# no face found !!!
# 367
# no face found !!!
# 368
# no face found !!!
# 369
# no face found !!!
# 370
# no face found !!!
# 371
# 372
# 373
# 374
# 375
# no face found !!!
# 376
# no face found !!!
# 377
# 378
# no face found !!!
# 379
# 380
# 381
# 382
# no face found !!!
# 383
# 384
# no face found !!!
# 385
# 386
# 387
# 388
# no face found !!!
# 389
# 390
# 391
# 392
# no face found !!!
# 393
# 394
# 395
# 396
# 397
# no face found !!!
# 398
# no face found !!!
# 399
# no face found !!!
# 400
# no face found !!!
# 401
# 402
# no face found !!!
# 403
# no face found !!!
# 404
# no face found !!!
# 405
# 406
# 407
# 408
# no face found !!!
# 409
# no face found !!!
# 410
# 411
# no face found !!!
# 412
# no face found !!!
# 413
# 414
# 415
# no face found !!!
# 416
# 417
# 418
# 419
# no face found !!!
# 420
# 421
# 422
# no face found !!!
# 423
# no face found !!!
# 424
# no face found !!!
# 425
# no face found !!!
# 426
# no face found !!!
# 427
# no face found !!!
# 428
# no face found !!!
# 429
# no face found !!!
# 430
# no face found !!!
# 431
# 432
# 433
# no face found !!!
# 434
# 435
# no face found !!!
# 436
# no face found !!!
# 437
# 438
# 439
# no face found !!!
# 440
# 441
# 442
# no face found !!!
# 443
# 444
# 445
# no face found !!!
# 446
# 447
# no face found !!!
# 448
# no face found !!!
# 449
# 450
# no face found !!!
# 451
# 452
# 453
# no face found !!!
# 454
# no face found !!!
# 455
# no face found !!!
# 456
# no face found !!!
# 457
# no face found !!!
# 458
# 459
# no face found !!!
# 460
# 461
# 462
# no face found !!!
# 463
# 464
# 465
# no face found !!!
# 466
# no face found !!!
# 467
# 468
# 469
# 470
# no face found !!!
# 471
# 472
# 473
# 474
# no face found !!!
# 475
# 476
# 477
# 478
# 479
# no face found !!!
# 480
# 481
# 482
# no face found !!!
# 483
# 484
# no face found !!!
# 485
# no face found !!!
# 486
# no face found !!!
# 487
# 488
# 489
# no face found !!!
# 490
# no face found !!!
# 491
# 492
# 493
# no face found !!!
# 494
# no face found !!!
# 495
# no face found !!!
# 496
# 497
# no face found !!!
# 498
# no face found !!!
# 499
# 500
# 501
# 502
# no face found !!!
# 503
# 504
# 505
# no face found !!!
# 506
# no face found !!!
# 507
# 508
# no face found !!!
# 509
# 510
# no face found !!!
# 511
# no face found !!!
# 512
# no face found !!!
# 513
# no face found !!!
# 514
# no face found !!!
# 515
# no face found !!!
# 516
# no face found !!!
# 517
# no face found !!!
# 518
# no face found !!!
# 519
# no face found !!!
# 520
# no face found !!!
# 521
# no face found !!!
# 522
# no face found !!!
# 523
# 524
# no face found !!!
# 525
# 526
# no face found !!!
# 527
# no face found !!!
# 528
# no face found !!!
# 529
# no face found !!!
# 530
# 531
# no face found !!!
# 532
# 533
# no face found !!!
# 534
# no face found !!!
# 535
# no face found !!!
# 536
# no face found !!!
# 537
# 538
# no face found !!!
# 539
# 540
# no face found !!!
# 541
# no face found !!!
# 542
# 543
# 544
# 545
# 546
# 547
# 548
# no face found !!!
# 549
# no face found !!!
# 550
# no face found !!!
# 551
# no face found !!!
# 552
# no face found !!!
# 553
# no face found !!!
# 554
# no face found !!!
# 555
# no face found !!!
# 556
# no face found !!!
# 557
# no face found !!!
# 558
# no face found !!!
# 559
# no face found !!!
# 560
# no face found !!!
# 561
# 562
# 563
# no face found !!!
# 564
# no face found !!!
# 565
# no face found !!!
# 566
# 567
# no face found !!!
# 568
# no face found !!!
# 569
# 570
# no face found !!!
# 571
# no face found !!!
# 572
# no face found !!!
# 573
# no face found !!!
# 574
# 575
# 576
# 577
# 578
# no face found !!!
# 579
# no face found !!!
# 580
# no face found !!!
# 581
# 582
# no face found !!!
# 583
# no face found !!!
# 584
# no face found !!!
# 585
# no face found !!!
# 586
# no face found !!!
# 587
# no face found !!!
# 588
# no face found !!!
# 589
# 590
# no face found !!!
# 591
# no face found !!!
# 592
# no face found !!!
# 593
# no face found !!!
# 594
# no face found !!!
# 595
# no face found !!!
# 596
# 597
# 598
# 599
# 600
# no face found !!!
# 601
# 602
# 603
# no face found !!!
# 604
# 605
# no face found !!!
# 606
# 607
# 608
# 609
# no face found !!!
# 610
# 611
# no face found !!!
# 612
# no face found !!!
# 613
# no face found !!!
# 614
# 615
# 616
# no face found !!!
# 617
# 618
# no face found !!!
# 619
# no face found !!!
# 620
# 621
# 622
# no face found !!!
# 623
# 624
# 625
# 626
# no face found !!!
# 627
# no face found !!!
# 628
# no face found !!!
# 629
# 630
# 631
# 632
# no face found !!!
# 633
# no face found !!!
# 634
# 635
# 636
# 637
# no face found !!!
# 638
# 639
# no face found !!!
# 640
# 641
# 642
# no face found !!!
# 643
# 644
# no face found !!!
# 645
# no face found !!!
# 646
# no face found !!!
# 647
# no face found !!!
# 648
# 649
# no face found !!!
# 650
# no face found !!!
# 651
# no face found !!!
# 652
# 653
# no face found !!!
# 654
# no face found !!!
# 655
# no face found !!!
# 656
# 657
# 658
# 659
# 660
# 661
# 662
# 663
# 664
# 665
# no face found !!!
# 666
# 667
# no face found !!!
# 668
# no face found !!!
# 669
# 670
# no face found !!!
# 671
# no face found !!!
# 672
# 673
# 674
# 675
# no face found !!!
# 676
# 677
# no face found !!!
# 678
# no face found !!!
# 679
# 680
# no face found !!!
# 681
# 682
# no face found !!!
# 683
# no face found !!!
# 684
# no face found !!!
# 685
# no face found !!!
# 686
# no face found !!!
# 687
# no face found !!!
# 688
# no face found !!!
# 689
# 690
# 691
# no face found !!!
# 692
# no face found !!!
# 693
# 694
# no face found !!!
# 695
# 696
# no face found !!!
# 697
# no face found !!!
# 698
# no face found !!!
# 699
# no face found !!!
# 700
# no face found !!!
# 701
# no face found !!!
# 702
# 703
# 704
# 705
# 706
# no face found !!!
# 707
# 708
# no face found !!!
# 709
# 710
# no face found !!!
# 711
# 712
# 713
# 714
# no face found !!!
# 715
# no face found !!!
# 716
# no face found !!!
# 717
# 718
# 719
# no face found !!!
# 720
# no face found !!!
# 721
# no face found !!!
# 722
# no face found !!!
# 723
# 724
# 725
# no face found !!!
# 726
# no face found !!!
# 727
# 728
# 729
# 730
# no face found !!!
# 731
# no face found !!!
# 732
# no face found !!!
# 733
# 734
# no face found !!!
# 735
# 736
# no face found !!!
# 737
# no face found !!!
# 738
# 739
# 740
# 741
# no face found !!!
# 742
# no face found !!!
# 743
# 744
# no face found !!!
# 745
# 746
# 747
# no face found !!!
# 748
# no face found !!!
# 749
# no face found !!!
# 750
# 751
# 752
# 753
# no face found !!!
# 754
# 755
# 756
# no face found !!!
# 757
# 758
# 759
# 760
# 761
# 762
# 763
# no face found !!!
# 764
# no face found !!!
# 765
# no face found !!!
# 766
# 767
# 768
# no face found !!!
# 769
# 770
# 771
# no face found !!!
# 772
# 773
# no face found !!!
# 774
# 775
# no face found !!!
# 776
# no face found !!!
# 777
# no face found !!!
# 778
# 779
# 780
# 781
# no face found !!!
# 782
# no face found !!!
# 783
# no face found !!!
# 784
# no face found !!!
# 785
# 786
# no face found !!!
# 787
# no face found !!!
# 788
# 789
# no face found !!!
# 790
# no face found !!!
# 791
# 792
# no face found !!!
# 793
# no face found !!!
# 794
# no face found !!!
# 795
# no face found !!!
# 796
# no face found !!!
# 797
# no face found !!!
# 798
# no face found !!!
# 799
# no face found !!!
# 800
# 801
# no face found !!!
# 802
# 803
# 804
# no face found !!!
# 805
# 806
# 807
# no face found !!!
# 808
# 809
# no face found !!!
# 810
# 811
# 812
# 813
# 814
# 815
# 816
# no face found !!!
# 817
# 818
# 819
# 820
# 821
# 822
# 823
# 824
# no face found !!!
# 825
# 826
# no face found !!!
# 827
# 828
# 829
# no face found !!!
# 830
# 831
# 832
# 833
# no face found !!!
# 834
# no face found !!!
# 835
# 836
# 837
# no face found !!!
# 838
# no face found !!!
# 839
# 840
# no face found !!!
# 841
# 842
# no face found !!!
# 843
# 844
# no face found !!!
# 845
# no face found !!!
# 846
# 847
# 848
# no face found !!!
# 849
# 850
# 851
# no face found !!!
# 852
# 853
# no face found !!!
# 854
# 855
# no face found !!!
# 856
# no face found !!!
# 857
# 858
# 859
# no face found !!!
# 860
# 861
# 862
# no face found !!!
# 863
# 864
# 865
# no face found !!!
# 866
# no face found !!!
# 867
# no face found !!!
# 868
# no face found !!!
# 869
# no face found !!!
# 870
# 871
# 872
# no face found !!!
# 873
# no face found !!!
# 874
# no face found !!!
# 875
# no face found !!!
# 876
# no face found !!!
# 877
# 878
# 879
# 880
# no face found !!!
# 881
# no face found !!!
# 882
# no face found !!!
# 883
# 884
# 885
# no face found !!!
# 886
# no face found !!!
# 887
# no face found !!!
# 888
# 889
# 890
# no face found !!!
# 891
# no face found !!!
# 892
# no face found !!!
# 893
# no face found !!!
# 894
# no face found !!!
# 895
# no face found !!!
# 896
# no face found !!!
# 897
# 898
# 899
# no face found !!!
# 900
# 901
# 902
# 903
# no face found !!!
# 904
# 905
# no face found !!!
# 906
# 907
# 908
# no face found !!!
# 909
# 910
# 911
# no face found !!!
# 912
# no face found !!!
# 913
# 914
# 915
# 916
# no face found !!!
# 917
# no face found !!!
# 918
# 919
# 920
# 921
# no face found !!!
# 922
# 923
# 924
# 925
# no face found !!!
# 926
# 927
# 928
# 929
# 930
# no face found !!!
# 931
# no face found !!!
# 932
# 933
# 934
# 935
# no face found !!!
# 936
# no face found !!!
# 937
# 938
# 939
# no face found !!!
# 940
# no face found !!!
# 941
# no face found !!!
# 942
# no face found !!!
# 943
# no face found !!!
# 944
# 945
# 946
# 947
# 948
# no face found !!!
# 949
# 950
# no face found !!!
# 951
# no face found !!!
# 952
# 953
# no face found !!!
# 954
# 955
# no face found !!!
# 956
# no face found !!!
# 957
# no face found !!!
# 958
# no face found !!!
# 959
# 960
# 961
# no face found !!!
# 962
# no face found !!!
# 963
# no face found !!!
# 964
# no face found !!!
# 965
# no face found !!!
# 966
# 967
# no face found !!!
# 968
# 969
# 970
# 971
# 972
# 973
# no face found !!!
# 974
# no face found !!!
# 975
# 976
# no face found !!!
# 977
# 978
# 979
# no face found !!!
# 980
# no face found !!!
# 981
# no face found !!!
# 982
# 983
# no face found !!!
# 984
# 985
# no face found !!!
# 986
# no face found !!!
# 987
# no face found !!!
# 988
# 989
# no face found !!!
# 990
# no face found !!!
# 991
# no face found !!!
# 992
# 993
# 994
# 995
# 996
# 997
# 998
# no face found !!!
# 999
# 1000
# no face found !!!
# 1001
# no face found !!!
# 1002
# no face found !!!
# 1003
# 1004
# no face found !!!
# 1005
# no face found !!!
# 1006
# 1007
# no face found !!!
# 1008
# no face found !!!
# 1009
# 1010
# 1011
# no face found !!!
# 1012
# no face found !!!
# 1013
# no face found !!!
# 1014
# 1015
# 1016
# 1017
# no face found !!!
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# no face found !!!
# 1025
# no face found !!!
# 1026
# no face found !!!
# 1027
# no face found !!!
# 1028
# 1029
# 1030
# no face found !!!
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# no face found !!!
# 1037
# 1038
# no face found !!!
# 1039
# 1040
# 1041
# no face found !!!
# 1042
# 1043
# no face found !!!
# 1044
# 1045
# no face found !!!
# 1046
# no face found !!!
# 1047
# no face found !!!
# 1048
# 1049
# 1050
# 1051
# no face found !!!
# 1052
# no face found !!!
# 1053
# 1054
# no face found !!!
# 1055
# no face found !!!
# 1056
# no face found !!!
# 1057
# no face found !!!
# 1058
# 1059
# 1060
# no face found !!!
# 1061
# no face found !!!
# 1062
# no face found !!!
# 1063
# no face found !!!
# 1064
# 1065
# no face found !!!
# 1066
# 1067
# no face found !!!
# 1068
# no face found !!!
# 1069
# 1070
# 1071
# 1072
# no face found !!!
# 1073
# 1074
# 1075
# 1076
# no face found !!!
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# no face found !!!
# 1083
# 1084
# no face found !!!
# 1085
# 1086
# no face found !!!
# 1087
# no face found !!!
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# no face found !!!
# 1096
# 1097
# 1098
# no face found !!!
# 1099
# 1100
# no face found !!!
# 1101
# no face found !!!
# 1102
# 1103
# no face found !!!
# 1104
# no face found !!!
# 1105
# 1106
# no face found !!!
# 1107
# no face found !!!
# 1108
# no face found !!!
# 1109
# no face found !!!
# 1110
# no face found !!!
# 1111
# no face found !!!
# 1112
# 1113
# 1114
# no face found !!!
# 1115
# 1116
# no face found !!!
# 1117
# 1118
# no face found !!!
# 1119
# 1120
# no face found !!!
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# no face found !!!
# 1128
# 1129
# 1130
# no face found !!!
# 1131
# 1132
# 1133
# no face found !!!
# 1134
# no face found !!!
# 1135
# no face found !!!
# 1136
# 1137
# no face found !!!
# 1138
# 1139
# no face found !!!
# 1140
# no face found !!!
# 1141
# no face found !!!
# 1142
# no face found !!!
# 1143
# no face found !!!
# 1144
# no face found !!!
# 1145
# 1146
# no face found !!!
# 1147
# no face found !!!
# 1148
# 1149
# no face found !!!
# 1150
# 1151
# no face found !!!
# 1152
# 1153
# no face found !!!
# 1154
# 1155
# 1156
# no face found !!!
# 1157
# 1158
# no face found !!!
# 1159
# no face found !!!
# 1160
# no face found !!!
# 1161
# no face found !!!
# 1162
# 1163
# no face found !!!
# 1164
# 1165
# 1166
# no face found !!!
# 1167
# 1168
# no face found !!!
# 1169
# no face found !!!
# 1170
# 1171
# 1172
# no face found !!!
# 1173
# 1174
# no face found !!!
# 1175
# no face found !!!
# 1176
# no face found !!!
# 1177
# no face found !!!
# 1178
# no face found !!!
# 1179
# no face found !!!
# 1180
# no face found !!!
# 1181
# no face found !!!
# 1182
# no face found !!!
# 1183
# no face found !!!
# 1184
# no face found !!!
# 1185
# no face found !!!
# 1186
# no face found !!!
# 1187
# 1188
# no face found !!!
# 1189
# 1190
# no face found !!!
# 1191
# no face found !!!
# 1192
# no face found !!!
# 1193
# 1194
# no face found !!!
# 1195
# no face found !!!
# 1196
# 1197
# 1198
# 1199
# no face found !!!
# 1200
# no face found !!!
# 1201
# no face found !!!
# 1202
# 1203
# 1204
# 1205
# 1206
# no face found !!!
# 1207
# 1208
# 1209
# no face found !!!
# 1210
# 1211
# no face found !!!
# 1212
# no face found !!!
# 1213
# 1214
# 1215
# 1216
# 1217
# no face found !!!
# 1218
# no face found !!!
# 1219
# no face found !!!
# 1220
# no face found !!!
# 1221
# no face found !!!
# 1222
# no face found !!!
# 1223
# no face found !!!
# 1224
# 1225
# no face found !!!
# 1226
# 1227
# 1228
# 1229
# no face found !!!
# 1230
# 1231
# no face found !!!
# 1232
# 1233
# no face found !!!
# 1234
# no face found !!!
# 1235
# 1236
# no face found !!!
# 1237
# 1238
# 1239
# no face found !!!
# 1240
# 1241
# 1242
# 1243
# 1244
# 1245
# 1246
# 1247
# no face found !!!
# 1248
# 1249
# no face found !!!
# 1250
# 1251
# 1252
# 1253
# 1254
# 1255
# no face found !!!
# 1256
# no face found !!!
# 1257
# no face found !!!
# 1258
# no face found !!!
# 1259
# 1260
# no face found !!!
# 1261
# no face found !!!
# 1262
# 1263
# no face found !!!
# 1264
# 1265
# no face found !!!
# 1266
# 1267
# 1268
# no face found !!!
# 1269
# no face found !!!
# 1270
# 1271
# no face found !!!
# 1272
# no face found !!!
# 1273
# no face found !!!
# 1274
# no face found !!!
# 1275
# 1276
# 1277
# no face found !!!
# 1278
# 1279
# no face found !!!
# 1280
# no face found !!!
# 1281
# no face found !!!
# 1282
# no face found !!!
# 1283
# no face found !!!
# 1284
# no face found !!!
# 1285
# 1286
# 1287
# 1288
# 1289
# 1290
# no face found !!!
# 1291
# no face found !!!
# 1292
# 1293
# no face found !!!
# 1294
# 1295
# 1296
# 1297
# 1298
# no face found !!!
# 1299
# 1300
# no face found !!!
# 1301
# 1302
# no face found !!!
# 1303
# 1304
# 1305
# 1306
# 1307
# 1308
# no face found !!!
# 1309
# no face found !!!
# 1310
# 1311
# no face found !!!
# 1312
# 1313
# no face found !!!
# 1314
# 1315
# no face found !!!
# 1316
# 1317
# no face found !!!
# 1318
# no face found !!!
# 1319
# no face found !!!
# 1320
# no face found !!!
# 1321
# no face found !!!
# 1322
# 1323
# 1324
# no face found !!!
# 1325
# no face found !!!
# 1326
# no face found !!!
# 1327
# no face found !!!
# 1328
# no face found !!!
# 1329
# no face found !!!
# 1330
# 1331
# no face found !!!
# 1332
# no face found !!!
# 1333
# 1334
# 1335
# no face found !!!
# 1336
# 1337
# no face found !!!
# 1338
# 1339
# no face found !!!
# 1340
# no face found !!!
# 1341
# no face found !!!
# 1342
# 1343
# 1344
# 1345
# 1346
# no face found !!!
# 1347
# 1348
# no face found !!!
# 1349
# no face found !!!
# 1350
# 1351
# 1352
# 1353
# 1354
# 1355
# 1356
# 1357
# 1358
# no face found !!!
# 1359
# no face found !!!
# 1360
# 1361
# 1362
# 1363
# 1364
# 1365
# no face found !!!
# 1366
# 1367
# 1368
# 1369
# 1370
# 1371
# no face found !!!
# 1372
# 1373
# 1374
# 1375
# 1376
# no face found !!!
# 1377
# no face found !!!
# 1378
# 1379
# 1380
# no face found !!!
# 1381
# no face found !!!
# 1382
# 1383
# no face found !!!
# 1384
# no face found !!!
# 1385
# 1386
# 1387
# 1388
# 1389
# 1390
# no face found !!!
# 1391
# 1392
# 1393
# 1394
# 1395
# no face found !!!
# 1396
# 1397
# no face found !!!
# 1398
# no face found !!!
# 1399
# 1400
# no face found !!!
# 1401
# 1402
# 1403
# 1404
# 1405
# 1406
# 1407
# 1408
# 1409
# 1410
# no face found !!!
# 1411
# no face found !!!
# 1412
# 1413
# 1414
# 1415
# 1416
# 1417
# 1418
# no face found !!!
# 1419
# no face found !!!
# 1420
# no face found !!!
# 1421
# 1422
# no face found !!!
# 1423
# no face found !!!
# 1424
# no face found !!!
# 1425
# no face found !!!
# 1426
# 1427
# no face found !!!
# 1428
# 1429
# no face found !!!
# 1430
# no face found !!!
# 1431
# 1432
# 1433
# no face found !!!
# 1434
# no face found !!!
# 1435
# no face found !!!
# 1436
# no face found !!!
# 1437
# no face found !!!
# 1438
# 1439
# 1440
# no face found !!!
# 1441
# no face found !!!
# 1442
# 1443
# 1444
# 1445
# 1446
# no face found !!!
# 1447
# 1448
# no face found !!!
# 1449
# 1450
# 1451
# 1452
# 1453
# 1454
# no face found !!!
# 1455
# 1456
# 1457
# 1458
# 1459
# 1460
# 1461
# 1462
# 1463
# no face found !!!
# 1464
# no face found !!!
# 1465
# 1466
# 1467
# no face found !!!
# 1468
# no face found !!!
# 1469
# 1470
# 1471
# no face found !!!
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1478
# no face found !!!
# 1479
# no face found !!!
# 1480
# no face found !!!
# 1481
# no face found !!!
# 1482
# no face found !!!
# 1483
# 1484
# no face found !!!
# 1485
# no face found !!!
# 1486
# no face found !!!
# 1487
# 1488
# 1489
# no face found !!!
# 1490
# 1491
# no face found !!!
# 1492
# no face found !!!
# 1493
# no face found !!!
# 1494
# 1495
# no face found !!!
# 1496
# no face found !!!
# 1497
# 1498
# no face found !!!
# 1499
# no face found !!!
# 1500
# no face found !!!
# 1501
# no face found !!!
# 1502
# 1503
# 1504
# no face found !!!
# 1505
# no face found !!!
# 1506
# 1507
# 1508
# 1509
# no face found !!!
# 1510
# no face found !!!
# 1511
# no face found !!!
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# 1518
# 1519
# no face found !!!
# 1520
# 1521
# no face found !!!
# 1522
# no face found !!!
# 1523
# 1524
# no face found !!!
# 1525
# 1526
# 1527
# 1528
# 1529
# 1530
# no face found !!!
# 1531
# no face found !!!
# 1532
# 1533
# 1534
# no face found !!!
# 1535
# no face found !!!
# 1536
# no face found !!!
# 1537
# 1538
# 1539
# no face found !!!
# 1540
# no face found !!!
# 1541
# no face found !!!
# 1542
# no face found !!!
# 1543
# no face found !!!
# 1544
# 1545
# no face found !!!
# 1546
# 1547
# no face found !!!
# 1548
# 1549
# no face found !!!
# 1550
# 1551
# 1552
# no face found !!!
# 1553
# no face found !!!
# 1554
# no face found !!!
# 1555
# no face found !!!
# 1556
# no face found !!!
# 1557
# 1558
# no face found !!!
# 1559
# 1560
# no face found !!!
# 1561
# 1562
# no face found !!!
# 1563
# no face found !!!
# 1564
# no face found !!!
# 1565
# no face found !!!
# 1566
# no face found !!!
# 1567
# no face found !!!
# 1568
# no face found !!!
# 1569
# no face found !!!
# 1570
# no face found !!!
# 1571
# no face found !!!
# 1572
# 1573
# no face found !!!
# 1574
# no face found !!!
# 1575
# no face found !!!
# 1576
# no face found !!!
# 1577
# 1578
# 1579
# 1580
# 1581
# 1582
# no face found !!!
# 1583
# 1584
# no face found !!!
# 1585
# 1586
# no face found !!!
# 1587
# 1588
# no face found !!!
# 1589
# 1590
# 1591
# no face found !!!
# 1592
# no face found !!!
# 1593
# 1594
# 1595
# 1596
# 1597
# no face found !!!
# 1598
# 1599
# no face found !!!
# 1600
# 1601
# 1602
# 1603
# no face found !!!
# 1604
# no face found !!!
# 1605
# no face found !!!
# 1606
# 1607
# no face found !!!
# 1608
# 1609
# 1610
# no face found !!!
# 1611
# no face found !!!
# 1612
# 1613
# 1614
# 1615
# 1616
# 1617
# 1618
# 1619
# 1620
# no face found !!!
# 1621
# no face found !!!
# 1622
# no face found !!!
# 1623
# 1624
# no face found !!!
# 1625
# 1626
# 1627
# 1628
# 1629
# no face found !!!
# 1630
# 1631
# 1632
# 1633
# 1634
# no face found !!!
# 1635
# 1636
# no face found !!!
# 1637
# no face found !!!
# 1638
# no face found !!!
# 1639
# no face found !!!
# 1640
# no face found !!!
# 1641
# no face found !!!
# 1642
# no face found !!!
# 1643
# no face found !!!
# 1644
# no face found !!!
# 1645
# no face found !!!
# 1646
# no face found !!!
# 1647
# no face found !!!
# 1648
# no face found !!!
# 1649
# no face found !!!
# 1650
# no face found !!!
# 1651
# no face found !!!
# 1652
# no face found !!!
# 1653
# no face found !!!
# 1654
# no face found !!!
# 1655
# no face found !!!
# 1656
# no face found !!!
# 1657
# no face found !!!
# 1658
# no face found !!!
# 1659
# no face found !!!
# 1660
# no face found !!!
# 1661
# no face found !!!
# 1662
# no face found !!!
# 1663
# no face found !!!
# 1664
# 1665
# 1666
# no face found !!!
# 1667
# no face found !!!
# 1668
# no face found !!!
# 1669
# no face found !!!
# 1670
# no face found !!!
# 1671
# no face found !!!
# 1672
# 1673
# no face found !!!
# 1674
# 1675
# no face found !!!
# 1676
# no face found !!!
# 1677
# no face found !!!
# 1678
# no face found !!!
# 1679
# 1680
# no face found !!!
# 1681
# 1682
# no face found !!!
# 1683
# no face found !!!
# 1684
# no face found !!!
# 1685
# no face found !!!
# 1686
# no face found !!!
# 1687
# 1688
# no face found !!!
# 1689
# 1690
# 1691
# no face found !!!
# 1692
# no face found !!!
# 1693
# 1694
# 1695
# 1696
# no face found !!!
# 1697
# 1698
# no face found !!!
# 1699
# 1700
# 1701
# 1702
# 1703
# 1704
# 1705
# 1706
# 1707
# 1708
# 1709
# 1710
# 1711
# 1712
# 1713
# 1714
# 1715
# 1716
# 1717
# 1718
# no face found !!!
# 1719
# 1720
# 1721
# 1722
# 1723
# 1724
# no face found !!!
# 1725
# no face found !!!
# 1726
# no face found !!!
# 1727
# no face found !!!
# 1728
# 1729
# no face found !!!
# 1730
# no face found !!!
# 1731
# no face found !!!
# 1732
# no face found !!!
# 1733
# no face found !!!
# 1734
# 1735
# 1736
# 1737
# no face found !!!
# 1738
# 1739
# 1740
# 1741
# no face found !!!
# 1742
# 1743
# no face found !!!
# 1744
# 1745
# 1746
# 1747
# no face found !!!
# 1748
# 1749
# no face found !!!
# 1750
# no face found !!!
# 1751
# no face found !!!
# 1752
# 1753
# 1754
# 1755
# 1756
# no face found !!!
# 1757
# 1758
# no face found !!!
# 1759
# no face found !!!
# 1760
# no face found !!!
# 1761
# 1762
# no face found !!!
# 1763
# no face found !!!
# 1764
# no face found !!!
# 1765
# no face found !!!
# 1766
# 1767
# 1768
# no face found !!!
# 1769
# no face found !!!
# 1770
# 1771
# 1772
# no face found !!!
# 1773
# no face found !!!
# 1774
# no face found !!!
# 1775
# 1776
# no face found !!!
# 1777
# no face found !!!
# 1778
# no face found !!!
# 1779
# no face found !!!
# 1780
# no face found !!!
# 1781
# 1782
# no face found !!!
# 1783
# no face found !!!
# 1784
# 1785
# no face found !!!
# 1786
# 1787
# 1788
# 1789
# no face found !!!
# 1790
# 1791
# no face found !!!
# 1792
# no face found !!!
# 1793
# 1794
# 1795
# no face found !!!
# 1796
# 1797
# 1798
# no face found !!!
# 1799
# 1800
# 1801
# no face found !!!
# 1802
# 1803
# no face found !!!
# 1804
# 1805
# no face found !!!
# 1806
# 1807
# 1808
# no face found !!!
# 1809
# 1810
# 1811
# no face found !!!
# 1812
# no face found !!!
# 1813
# no face found !!!
# 1814
# no face found !!!
# 1815
# no face found !!!
# 1816
# no face found !!!
# 1817
# no face found !!!
# 1818
# no face found !!!
# 1819
# 1820
# 1821
# 1822
# 1823
# 1824
# 1825
# 1826
# no face found !!!
# 1827
# 1828
# 1829
# 1830
# 1831
# 1832
# 1833
# 1834
# 1835
# 1836
# 1837
# 1838
# 1839
# 1840
# 1841
# 1842
# 1843
# no face found !!!
# 1844
# no face found !!!
# 1845
# 1846
# 1847
# no face found !!!
# 1848
# no face found !!!
# 1849
# no face found !!!
# 1850
# no face found !!!
# 1851
# 1852
# 1853
# no face found !!!
# 1854
# no face found !!!
# 1855
# 1856
# 1857
# 1858
# no face found !!!
# 1859
# no face found !!!
# 1860
# 1861
# 1862
# no face found !!!
# 1863
# no face found !!!
# 1864
# 1865
# 1866
# no face found !!!
# 1867
# 1868
# no face found !!!
# 1869
# no face found !!!
# 1870
# no face found !!!
# 1871
# no face found !!!
# 1872
# 1873
# no face found !!!
# 1874
# no face found !!!
# 1875
# no face found !!!
# 1876
# no face found !!!
# 1877
# no face found !!!
# 1878
# no face found !!!
# 1879
# 1880
# no face found !!!
# 1881
# no face found !!!
# 1882
# 1883
# 1884
# no face found !!!
# 1885
# no face found !!!
# 1886
# no face found !!!
# 1887
# 1888
# no face found !!!
# 1889
# no face found !!!
# 1890
# no face found !!!
# 1891
# 1892
# no face found !!!
# 1893
# no face found !!!
# 1894
# 1895
# no face found !!!
# 1896
# no face found !!!
# 1897
# no face found !!!
# 1898
# 1899
# 1900
# 1901
# no face found !!!
# 1902
# 1903
# no face found !!!
# 1904
# no face found !!!
# 1905
# 1906
# no face found !!!
# 1907
# 1908
# no face found !!!
# 1909
# no face found !!!
# 1910
# no face found !!!
# 1911
# 1912
# no face found !!!
# 1913
# no face found !!!
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# no face found !!!
# 1920
# no face found !!!
# 1921
# no face found !!!
# 1922
# no face found !!!
# 1923
# 1924
# no face found !!!
# 1925
# 1926
# 1927
# 1928
# no face found !!!
# 1929
# no face found !!!
# 1930
# no face found !!!
# 1931
# no face found !!!
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# no face found !!!
# 1938
# 1939
# 1940
# 1941
# no face found !!!
# 1942
# 1943
# no face found !!!
# 1944
# no face found !!!
# 1945
# no face found !!!
# 1946
# no face found !!!
# 1947
# no face found !!!
# 1948
# no face found !!!
# 1949
# no face found !!!
# 1950
# 1951
# no face found !!!
# 1952
# no face found !!!
# 1953
# 1954
# no face found !!!
# 1955
# 1956
# 1957
# no face found !!!
# 1958
# 1959
# no face found !!!
# 1960
# 1961
# 1962
# no face found !!!
# 1963
# no face found !!!
# 1964
# 1965
# 1966
# 1967
# no face found !!!
# 1968
# 1969
# 1970
# 1971
# 1972
# no face found !!!
# 1973
# 1974
# no face found !!!
# 1975
# no face found !!!
# 1976
# 1977
# 1978
# no face found !!!
# 1979
# 1980
# 1981
# no face found !!!
# 1982
# 1983
# no face found !!!
# 1984
# no face found !!!
# 1985
# no face found !!!
# 1986
# 1987
# 1988
# no face found !!!
# 1989
# no face found !!!
# 1990
# no face found !!!
# 1991
# no face found !!!
# 1992
# 1993
# no face found !!!
# 1994
# no face found !!!
# 1995
# no face found !!!
# 1996
# no face found !!!
# 1997
# no face found !!!
# 1998
# 1999
# no face found !!!
# 2000
# 2001
# no face found !!!
# 2002
# 2003
# no face found !!!
# 2004
# 2005
# 2006
# 2007
# no face found !!!
# 2008
# 2009
# 2010
# no face found !!!
# 2011
# no face found !!!
# 2012
# no face found !!!
# 2013
# 2014
# no face found !!!
# 2015
# no face found !!!
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# no face found !!!
# 2022
# 2023
# no face found !!!
# 2024
# no face found !!!
# 2025
# no face found !!!
# 2026
# 2027
# 2028
# no face found !!!
# 2029
# 2030
# no face found !!!
# 2031
# 2032
# no face found !!!
# 2033
# 2034
# no face found !!!
# 2035
# no face found !!!
# 2036
# 2037
# no face found !!!
# 2038
# no face found !!!
# 2039
# no face found !!!
# 2040
# no face found !!!
# 2041
# no face found !!!
# 2042
# no face found !!!
# 2043
# no face found !!!
# 2044
# 2045
# 2046
# no face found !!!
# 2047
# no face found !!!
# 2048
# no face found !!!
# 2049
# 2050
# no face found !!!
# 2051
# no face found !!!
# 2052
# no face found !!!
# 2053
# no face found !!!
# 2054
# no face found !!!
# 2055
# no face found !!!
# 2056
# no face found !!!
# 2057
# no face found !!!
# 2058
# 2059
# no face found !!!
# 2060
# no face found !!!
# 2061
# no face found !!!
# 2062
# no face found !!!
# 2063
# 2064
# 2065
# no face found !!!
# 2066
# 2067
# no face found !!!
# 2068
# 2069
# 2070
# no face found !!!
# 2071
# no face found !!!
# 2072
# no face found !!!
# 2073
# 2074
# 2075
# no face found !!!
# 2076
# no face found !!!
# 2077
# 2078
# no face found !!!
# 2079
# no face found !!!
# 2080
# no face found !!!
# 2081
# no face found !!!
# 2082
# no face found !!!
# 2083
# no face found !!!
# 2084
# no face found !!!
# 2085
# 2086
# 2087
# 2088
# 2089
# 2090
# 2091
# 2092
# 2093
# no face found !!!
# 2094
# 2095
# no face found !!!
# 2096
# no face found !!!
# 2097
# no face found !!!
# 2098
# no face found !!!
# 2099
# 2100
# 2101
# no face found !!!
# 2102
# no face found !!!
# 2103
# 2104
# 2105
# 2106
# 2107
# no face found !!!
# 2108
# no face found !!!
# 2109
# no face found !!!
# 2110
# no face found !!!
# 2111
# no face found !!!
# 2112
# no face found !!!
# 2113
# no face found !!!
# 2114
# no face found !!!
# 2115
# no face found !!!
# 2116
# no face found !!!
# 2117
# 2118
# no face found !!!
# 2119
# 2120
# 2121
# 2122
# 2123
# 2124
# 2125
# 2126
# no face found !!!
# 2127
# 2128
# no face found !!!
# 2129
# 2130
# 2131
# no face found !!!
# 2132
# no face found !!!
# 2133
# 2134
# no face found !!!
# 2135
# no face found !!!
# 2136
# no face found !!!
# 2137
# 2138
# no face found !!!
# 2139
# 2140
# no face found !!!
# 2141
# no face found !!!
# 2142
# no face found !!!
# 2143
# 2144
# 2145
# 2146
# 2147
# 2148
# 2149
# no face found !!!
# 2150
# no face found !!!
# 2151
# no face found !!!
# 2152
# 2153
# no face found !!!
# 2154
# 2155
# no face found !!!
# 2156
# 2157
# 2158
# no face found !!!
# 2159
# 2160
# no face found !!!
# 2161
# 2162
# no face found !!!
# 2163
# 2164
# 2165
# 2166
# 2167
# 2168
# 2169
# 2170
# no face found !!!
# 2171
# 2172
# no face found !!!
# 2173
# no face found !!!
# 2174
# no face found !!!
# 2175
# 2176
# no face found !!!
# 2177
# no face found !!!
# 2178
# 2179
# no face found !!!
# 2180
# 2181
# 2182
# 2183
# 2184
# no face found !!!
# 2185
# no face found !!!
# 2186
# 2187
# 2188
# 2189
# no face found !!!
# 2190
# 2191
# 2192
# no face found !!!
# 2193
# 2194
# no face found !!!
# 2195
# 2196
# 2197
# no face found !!!
# 2198
# no face found !!!
# 2199
# no face found !!!
# 2200
# no face found !!!
# 2201
# no face found !!!
# 2202
# no face found !!!
# 2203
# no face found !!!
# 2204
# no face found !!!
# 2205
# no face found !!!
# 2206
# no face found !!!
# 2207
# 2208
# 2209
# no face found !!!
# 2210
# no face found !!!
# 2211
# no face found !!!
# 2212
# no face found !!!
# 2213
# no face found !!!
# 2214
# no face found !!!
# 2215
# 2216
# 2217
# no face found !!!
# 2218
# no face found !!!
# 2219
# 2220
# 2221
# no face found !!!
# 2222
# 2223
# no face found !!!
# 2224
# no face found !!!
# 2225
# no face found !!!
# 2226
# no face found !!!
# 2227
# no face found !!!
# 2228
# 2229
# 2230
# 2231
# no face found !!!
# 2232
# 2233
# 2234
# 2235
# 2236
# no face found !!!
# 2237
# no face found !!!
# 2238
# 2239
# no face found !!!
# 2240
# no face found !!!
# 2241
# 2242
# no face found !!!
# 2243
# no face found !!!
# 2244
# no face found !!!
# 2245
# no face found !!!
# 2246
# 2247
# 2248
# 2249
# no face found !!!
# 2250
# 2251
# no face found !!!
# 2252
# no face found !!!
# 2253
# no face found !!!
# 2254
# no face found !!!
# 2255
# no face found !!!
# 2256
# no face found !!!
# 2257
# no face found !!!
# 2258
# no face found !!!
# 2259
# no face found !!!
# 2260
# no face found !!!
# 2261
# no face found !!!
# 2262
# no face found !!!
# 2263
# 2264
# 2265
# no face found !!!
# 2266
# no face found !!!
# 2267
# 2268
# 2269
# no face found !!!
# 2270
# 2271
# no face found !!!
# 2272
# 2273
# 2274
# no face found !!!
# 2275
# no face found !!!
# 2276
# no face found !!!
# 2277
# 2278
# no face found !!!
# 2279
# 2280
# no face found !!!
# 2281
# no face found !!!
# 2282
# 2283
# no face found !!!
# 2284
# no face found !!!
# 2285
# no face found !!!
# 2286
# 2287
# no face found !!!
# 2288
# no face found !!!
# 2289
# 2290
# no face found !!!
# 2291
# no face found !!!
# 2292
# no face found !!!
# 2293
# no face found !!!
# 2294
# 2295
# no face found !!!
# 2296
# no face found !!!
# 2297
# no face found !!!
# 2298
# 2299
# no face found !!!
# 2300
# no face found !!!
# 2301
# no face found !!!
# 2302
# no face found !!!
# 2303
# no face found !!!
# 2304
# no face found !!!
# 2305
# no face found !!!
# 2306
# 2307
# no face found !!!
# 2308
# no face found !!!
# 2309
# 2310
# 2311
# 2312
# no face found !!!
# 2313
# 2314
# 2315
# 2316
# 2317
# no face found !!!
# 2318
# 2319
# 2320
# no face found !!!
# 2321
# 2322
# 2323
# no face found !!!
# 2324
# 2325
# 2326
# no face found !!!
# 2327
# 2328
# no face found !!!
# 2329
# no face found !!!
# 2330
# 2331
# no face found !!!
# 2332
# no face found !!!
# 2333
# no face found !!!
# 2334
# no face found !!!
# 2335
# no face found !!!
# 2336
# 2337
# 2338
# 2339
# 2340
# 2341
# no face found !!!
# 2342
# 2343
# 2344
# 2345
# no face found !!!
# 2346
# 2347
# 2348
# no face found !!!
# 2349
# no face found !!!
# 2350
# no face found !!!
# 2351
# no face found !!!
# 2352
# 2353
# 2354
# 2355
# no face found !!!
# 2356
# 2357
# no face found !!!
# 2358
# 2359
# 2360
# no face found !!!
# 2361
# no face found !!!
# 2362
# 2363
# no face found !!!
# 2364
# 2365
# 2366
# no face found !!!
# 2367
# no face found !!!
# 2368
# no face found !!!
# 2369
# 2370
# no face found !!!
# 2371
# 2372
# 2373
# no face found !!!
# 2374
# 2375
# no face found !!!
# 2376
# no face found !!!
# 2377
# 2378
# 2379
# 2380
# no face found !!!
# 2381
# 2382
# 2383
# no face found !!!
# 2384
# no face found !!!
# 2385
# no face found !!!
# 2386
# no face found !!!
# 2387
# no face found !!!
# 2388
# no face found !!!
# 2389
# 2390
# no face found !!!
# 2391
# 2392
# no face found !!!
# 2393
# no face found !!!
# 2394
# no face found !!!
# 2395
# no face found !!!
# 2396
# 2397
# 2398
# no face found !!!
# 2399
# no face found !!!
# 2400
# no face found !!!
# 2401
# 2402
# no face found !!!
# 2403
# no face found !!!
# 2404
# no face found !!!
# 2405
# no face found !!!
# 2406
# 2407
# 2408
# no face found !!!
# 2409
# no face found !!!
# 2410
# 2411
# no face found !!!
# 2412
# 2413
# no face found !!!
# 2414
# 2415
# 2416
# no face found !!!
# 2417
# no face found !!!
# 2418
# 2419
# no face found !!!
# 2420
# no face found !!!
# 2421
# no face found !!!
# 2422
# no face found !!!
# 2423
# no face found !!!
# 2424
# no face found !!!
# 2425
# no face found !!!
# 2426
# no face found !!!
# 2427
# no face found !!!
# 2428
# 2429
# 2430
# no face found !!!
# 2431
# 2432
# no face found !!!
# 2433
# 2434
# no face found !!!
# 2435
# no face found !!!
# 2436
# no face found !!!
# 2437
# no face found !!!
# 2438
# 2439
# 2440
# 2441
# 2442
# no face found !!!
# 2443
# 2444
# no face found !!!
# 2445
# no face found !!!
# 2446
# no face found !!!
# 2447
# 2448
# no face found !!!
# 2449
# 2450
# no face found !!!
# 2451
# no face found !!!
# 2452
# no face found !!!
# 2453
# no face found !!!
# 2454
# no face found !!!
# 2455
# 2456
# no face found !!!
# 2457
# 2458
# no face found !!!
# 2459
# no face found !!!
# 2460
# no face found !!!
# 2461
# no face found !!!
# 2462
# no face found !!!
# 2463
# no face found !!!
# 2464
# 2465
# no face found !!!
# 2466
# no face found !!!
# 2467
# no face found !!!
# 2468
# 2469
# no face found !!!
# 2470
# no face found !!!
# 2471
# 2472
# no face found !!!
# 2473
# 2474
# 2475
# no face found !!!
# 2476
# 2477
# no face found !!!
# 2478
# no face found !!!
# 2479
# 2480
# no face found !!!
# 2481
# no face found !!!
# 2482
# 2483
# 2484
# 2485
# no face found !!!
# 2486
# 2487
# no face found !!!
# 2488
# 2489
# no face found !!!
# 2490
# 2491
# 2492
# 2493
# no face found !!!
# 2494
# no face found !!!
# 2495
# 2496
# no face found !!!
# 2497
# 2498
# 2499
# 2500
# 2501
# 2502
# 2503
# 2504
# 2505
# no face found !!!
# 2506
# no face found !!!
# 2507
# 2508
# no face found !!!
# 2509
# 2510
# 2511
# 2512
# 2513
# 2514
# 2515
# 2516
# no face found !!!
# 2517
# no face found !!!
# 2518
# no face found !!!
# 2519
# no face found !!!
# 2520
# no face found !!!
# 2521
# no face found !!!
# 2522
# no face found !!!
# 2523
# no face found !!!
# 2524
# no face found !!!
# 2525
# no face found !!!
# 2526
# no face found !!!
# 2527
# no face found !!!
# 2528
# 2529
# 2530
# 2531
# no face found !!!
# 2532
# 2533
# 2534
# no face found !!!
# 2535
# 2536
# 2537
# 2538
# 2539
# 2540
# no face found !!!
# 2541
# no face found !!!
# 2542
# no face found !!!
# 2543
# no face found !!!
# 2544
# no face found !!!
# 2545
# no face found !!!
# 2546
# no face found !!!
# 2547
# no face found !!!
# 2548
# 2549
# 2550
# no face found !!!
# 2551
# no face found !!!
# 2552
# 2553
# no face found !!!
# 2554
# no face found !!!
# 2555
# no face found !!!
# 2556
# no face found !!!
# 2557
# no face found !!!
# 2558
# 2559
# no face found !!!
# 2560
# no face found !!!
# 2561
# no face found !!!
# 2562
# no face found !!!
# 2563
# no face found !!!
# 2564
# no face found !!!
# 2565
# 2566
# no face found !!!
# 2567
# no face found !!!
# 2568
# 2569
# 2570
# no face found !!!
# 2571
# 2572
# no face found !!!
# 2573
# 2574
# 2575
# 2576
# 2577
# no face found !!!
# 2578
# no face found !!!
# 2579
# no face found !!!
# 2580
# no face found !!!
# 2581
# no face found !!!
# 2582
# no face found !!!
# 2583
# no face found !!!
# 2584
# no face found !!!
# 2585
# no face found !!!
# 2586
# no face found !!!
# 2587
# no face found !!!
# 2588
# no face found !!!
# 2589
# no face found !!!
# 2590
# no face found !!!
# 2591
# no face found !!!
# 2592
# no face found !!!
# 2593
# no face found !!!
# 2594
# no face found !!!
# 2595
# no face found !!!
# 2596
# no face found !!!
# 2597
# no face found !!!
# 2598
# no face found !!!
# 2599
# no face found !!!
# 2600
# 2601
# 2602
# no face found !!!
# 2603
# no face found !!!
# 2604
# 2605
# 2606
# no face found !!!
# 2607
# 2608
# no face found !!!
# 2609
# 2610
# no face found !!!
# 2611
# 2612
# 2613
# 2614
# 2615
# 2616
# no face found !!!
# 2617
# no face found !!!
# 2618
# 2619
# no face found !!!
# 2620
# no face found !!!
# 2621
# 2622
# 2623
# 2624
# 2625
# 2626
# 2627
# no face found !!!
# 2628
# 2629
# 2630
# 2631
# 2632
# 2633
# 2634
# 2635
# 2636
# 2637
# no face found !!!
# 2638
# no face found !!!
# 2639
# 2640
# 2641
# 2642
# 2643
# no face found !!!
# 2644
# 2645
# 2646
# 2647
# 2648
# 2649
# 2650
# 2651
# 2652
# 2653
# 2654
# no face found !!!
# 2655
# 2656
# 2657
# 2658
# 2659
# 2660
# 2661
# 2662
# 2663
# 2664
# no face found !!!
# 2665
# 2666
# 2667
# no face found !!!
# 2668
# 2669
# 2670
# 2671
# no face found !!!
# 2672
# no face found !!!
# 2673
# no face found !!!
# 2674
# 2675
# 2676
# no face found !!!
# 2677
# 2678
# 2679
# no face found !!!
# 2680
# 2681
# no face found !!!
# 2682
# no face found !!!
# 2683
# no face found !!!
# 2684
# no face found !!!
# 2685
# no face found !!!
# 2686
# 2687
# 2688
# 2689
# 2690
# 2691
# 2692
# 2693
# 2694
# 2695
# 2696
# no face found !!!
# 2697
# no face found !!!
# 2698
# 2699
# no face found !!!
# 2700
# no face found !!!
# 2701
# 2702
# 2703
# 2704
# no face found !!!
# 2705
# 2706
# no face found !!!
# 2707
# no face found !!!
# 2708
# no face found !!!
# 2709
# no face found !!!
# 2710
# 2711
# no face found !!!
# 2712
# no face found !!!
# 2713
# no face found !!!
# 2714
# 2715
# no face found !!!
# 2716
# no face found !!!
# 2717
# no face found !!!
# 2718
# no face found !!!
# 2719
# 2720
# 2721
# 2722
# 2723
# no face found !!!
# 2724
# 2725
# no face found !!!
# 2726
# no face found !!!
# 2727
# no face found !!!
# 2728
# no face found !!!
# 2729
# no face found !!!
# 2730
# 2731
# no face found !!!
# 2732
# no face found !!!
# 2733
# no face found !!!
# 2734
# no face found !!!
# 2735
# no face found !!!
# 2736
# no face found !!!
# 2737
# no face found !!!
# 2738
# no face found !!!
# 2739
# no face found !!!
# 2740
# no face found !!!
# 2741
# no face found !!!
# 2742
# no face found !!!
# 2743
# no face found !!!
# 2744
# 2745
# 2746
# no face found !!!
# 2747
# 2748
# no face found !!!
# 2749
# 2750
# 2751
# no face found !!!
# 2752
# 2753
# no face found !!!
# 2754
# 2755
# 2756
# no face found !!!
# 2757
# 2758
# no face found !!!
# 2759
# 2760
# no face found !!!
# 2761
# 2762
# no face found !!!
# 2763
# 2764
# 2765
# no face found !!!
# 2766
# 2767
# no face found !!!
# 2768
# 2769
# no face found !!!
# 2770
# 2771
# 2772
# 2773
# 2774
# 2775
# 2776
# 2777
# no face found !!!
# 2778
# 2779
# 2780
# 2781
# no face found !!!
# 2782
# 2783
# no face found !!!
# 2784
# 2785
# 2786
# 2787
# 2788
# 2789
# no face found !!!
# 2790
# no face found !!!
# 2791
# 2792
# 2793
# 2794
# 2795
# no face found !!!
# 2796
# no face found !!!
# 2797
# no face found !!!
# 2798
# 2799
# 2800
# 2801
# no face found !!!
# 2802
# no face found !!!
# 2803
# 2804
# 2805
# 2806
# no face found !!!
# 2807
# 2808
# no face found !!!
# 2809
# no face found !!!
# 2810
# no face found !!!
# 2811
# no face found !!!
# 2812
# no face found !!!
# 2813
# 2814
# no face found !!!
# 2815
# no face found !!!
# 2816
# 2817
# 2818
# 2819
# 2820
# no face found !!!
# 2821
# 2822
# 2823
# 2824
# 2825
# 2826
# 2827
# 2828
# 2829
# no face found !!!
# 2830
# no face found !!!
# 2831
# no face found !!!
# 2832
# no face found !!!
# 2833
# no face found !!!
# 2834
# 2835
# 2836
# no face found !!!
# 2837
# 2838
# no face found !!!
# 2839
# no face found !!!
# 2840
# 2841
# no face found !!!
# 2842
# no face found !!!
# 2843
# no face found !!!
# 2844
# no face found !!!
# 2845
# no face found !!!
# 2846
# no face found !!!
# 2847
# no face found !!!
# 2848
# 2849
# 2850
# no face found !!!
# 2851
# no face found !!!
# 2852
# 2853
# no face found !!!
# 2854
# 2855
# 2856
# 2857
# 2858
# 2859
# 2860
# 2861
# 2862
# no face found !!!
# 2863
# 2864
# no face found !!!
# 2865
# no face found !!!
# 2866
# no face found !!!
# 2867
# no face found !!!
# 2868
# 2869
# no face found !!!
# 2870
# 2871
# no face found !!!
# 2872
# 2873
# 2874
# 2875
# 2876
# 2877
# no face found !!!
# 2878
# 2879
# 2880
# 2881
# 2882
# 2883
# 2884
# 2885
# no face found !!!
# 2886
# 2887
# no face found !!!
# 2888
# no face found !!!
# 2889
# no face found !!!
# 2890
# 2891
# 2892
# 2893
# no face found !!!
# 2894
# no face found !!!
# 2895
# no face found !!!
# 2896
# no face found !!!
# 2897
# 2898
# no face found !!!
# 2899
# no face found !!!
# 2900
# 2901
# no face found !!!
# 2902
# no face found !!!
# 2903
# 2904
# no face found !!!
# 2905
# 2906
# no face found !!!
# 2907
# 2908
# no face found !!!
# 2909
# no face found !!!
# 2910
# 2911
# no face found !!!
# 2912
# 2913
# no face found !!!
# 2914
# 2915
# 2916
# 2917
# 2918
# 2919
# no face found !!!
# 2920
# no face found !!!
# 2921
# no face found !!!
# 2922
# no face found !!!
# 2923
# no face found !!!
# 2924
# no face found !!!
# 2925
# 2926
# no face found !!!
# 2927
# no face found !!!
# 2928
# no face found !!!
# 2929
# 2930
# no face found !!!
# 2931
# no face found !!!
# 2932
# no face found !!!
# 2933
# no face found !!!
# 2934
# 2935
# no face found !!!
# 2936
# 2937
# 2938
# no face found !!!
# 2939
# no face found !!!
# 2940
# no face found !!!
# 2941
# no face found !!!
# 2942
# no face found !!!
# 2943
# no face found !!!
# 2944
# no face found !!!
# 2945
# no face found !!!
# 2946
# 2947
# 2948
# 2949
# 2950
# no face found !!!
# 2951
# no face found !!!
# 2952
# no face found !!!
# 2953
# 2954
# 2955
# no face found !!!
# 2956
# 2957
# 2958
# no face found !!!
# 2959
# 2960
# 2961
# no face found !!!
# 2962
# no face found !!!
# 2963
# no face found !!!
# 2964
# no face found !!!
# 2965
# no face found !!!
# 2966
# 2967
# no face found !!!
# 2968
# 2969
# no face found !!!
# 2970
# no face found !!!
# 2971
# no face found !!!
# 2972
# no face found !!!
# 2973
# 2974
# no face found !!!
# 2975
# no face found !!!
# 2976
# no face found !!!
# 2977
# 2978
# 2979
# no face found !!!
# 2980
# no face found !!!
# 2981
# 2982
# 2983
# 2984
# 2985
# no face found !!!
# 2986
# no face found !!!
# 2987
# no face found !!!
# 2988
# no face found !!!
# 2989
# 2990
# 2991
# 2992
# 2993
# 2994
# no face found !!!
# 2995
# no face found !!!
# 2996
# 2997
# 2998
# 2999
# no face found !!!
# 3000
# 3001
# no face found !!!
# 3002
# 3003
# no face found !!!
# 3004
# no face found !!!
# 3005
# no face found !!!
# 3006
# no face found !!!
# 3007
# no face found !!!
# 3008
# no face found !!!
# 3009
# no face found !!!
# 3010
# no face found !!!
# 3011
# no face found !!!
# 3012
# no face found !!!
# 3013
# no face found !!!
# 3014
# no face found !!!
# 3015
# no face found !!!
# 3016
# no face found !!!
# 3017
# 3018
# no face found !!!
# 3019
# no face found !!!
# 3020
# no face found !!!
# 3021
# no face found !!!
# 3022
# 3023
# no face found !!!
# 3024
# 3025
# 3026
# no face found !!!
# 3027
# no face found !!!
# 3028
# no face found !!!
# 3029
# 3030
# 3031
# no face found !!!
# 3032
# 3033
# 3034
# 3035
# 3036
# no face found !!!
# 3037
# 3038
# 3039
# 3040
# no face found !!!
# 3041
# no face found !!!
# 3042
# no face found !!!
# 3043
# no face found !!!
# 3044
# 3045
# no face found !!!
# 3046
# 3047
# 3048
# no face found !!!
# 3049
# no face found !!!
# 3050
# 3051
# no face found !!!
# 3052
# no face found !!!
# 3053
# no face found !!!
# 3054
# no face found !!!
# 3055
# 3056
# no face found !!!
# 3057
# no face found !!!
# 3058
# 3059
# no face found !!!
# 3060
# no face found !!!
# 3061
# no face found !!!
# 3062
# no face found !!!
# 3063
# no face found !!!
# 3064
# no face found !!!
# 3065
# no face found !!!
# 3066
# no face found !!!
# 3067
# no face found !!!
# 3068
# no face found !!!
# 3069
# no face found !!!
# 3070
# 3071
# no face found !!!
# 3072
# no face found !!!
# 3073
# 3074
# 3075
# no face found !!!
# 3076
# no face found !!!
# 3077
# 3078
# no face found !!!
# 3079
# no face found !!!
# 3080
# 3081
# 3082
# no face found !!!
# 3083
# no face found !!!
# 3084
# no face found !!!
# 3085
# 3086
# no face found !!!
# 3087
# 3088
# 3089
# 3090
# no face found !!!
# 3091
# no face found !!!
# 3092
# no face found !!!
# 3093
# no face found !!!
# 3094
# 3095
# 3096
# no face found !!!
# 3097
# no face found !!!
# 3098
# no face found !!!
# 3099
# no face found !!!
# 3100
# no face found !!!
# 3101
# no face found !!!
# 3102
# 3103
# 3104
# no face found !!!
# 3105
# 3106
# 3107
# 3108
# 3109
# no face found !!!
# 3110
# 3111
# 3112
# 3113
# 3114
# 3115
# no face found !!!
# 3116
# no face found !!!
# 3117
# no face found !!!
# 3118
# no face found !!!
# 3119
# 3120
# no face found !!!
# 3121
# no face found !!!
# 3122
# 3123
# 3124
# 3125
# 3126
# 3127
# 3128
# 3129
# 3130
# no face found !!!
# 3131
# no face found !!!
# 3132
# no face found !!!
# 3133
# no face found !!!
# 3134
# no face found !!!
# 3135
# no face found !!!
# 3136
# no face found !!!
# 3137
# no face found !!!
# 3138
# no face found !!!
# 3139
# no face found !!!
# 3140
# no face found !!!
# 3141
# no face found !!!
# 3142
# no face found !!!
# 3143
# no face found !!!
# 3144
# 3145
# no face found !!!
# 3146
# no face found !!!
# 3147
# no face found !!!
# 3148
# no face found !!!
# 3149
# 3150
# no face found !!!
# 3151
# 3152
# no face found !!!
# 3153
# 3154
# 3155
# no face found !!!
# 3156
# no face found !!!
# 3157
# no face found !!!
# 3158
# 3159
# 3160
# no face found !!!
# 3161
# 3162
# no face found !!!
# 3163
# 3164
# no face found !!!
# 3165
# 3166
# 3167
# no face found !!!
# 3168
# no face found !!!
# 3169
# no face found !!!
# 3170
# 3171
# no face found !!!
# 3172
# 3173
# no face found !!!
# 3174
# 3175
# no face found !!!
# 3176
# 3177
# no face found !!!
# 3178
# no face found !!!
# 3179
# no face found !!!
# 3180
# no face found !!!
# 3181
# 3182
# no face found !!!
# 3183
# no face found !!!
# 3184
# 3185
# no face found !!!
# 3186
# no face found !!!
# 3187
# no face found !!!
# 3188
# no face found !!!
# 3189
# 3190
# no face found !!!
# 3191
# 3192
# 3193
# no face found !!!
# 3194
# no face found !!!
# 3195
# 3196
# no face found !!!
# 3197
# 3198
# no face found !!!
# 3199
# no face found !!!
# 3200
# no face found !!!
# 3201
# no face found !!!
# 3202
# no face found !!!
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3218
# no face found !!!
# 3219
# no face found !!!
# 3220
# no face found !!!
# 3221
# 3222
# no face found !!!
# 3223
# 3224
# no face found !!!
# 3225
# no face found !!!
# 3226
# no face found !!!
# 3227
# no face found !!!
# 3228
# no face found !!!
# 3229
# 3230
# no face found !!!
# 3231
# no face found !!!
# 3232
# no face found !!!
# 3233
# no face found !!!
# 3234
# 3235
# 3236
# no face found !!!
# 3237
# no face found !!!
# 3238
# no face found !!!
# 3239
# 3240
# no face found !!!
# 3241
# 3242
# 3243
# 3244
# 3245
# 3246
# no face found !!!
# 3247
# 3248
# no face found !!!
# 3249
# no face found !!!
# 3250
# no face found !!!
# 3251
# no face found !!!
# 3252
# 3253
# no face found !!!
# 3254
# 3255
# no face found !!!
# 3256
# 3257
# no face found !!!
# 3258
# no face found !!!
# 3259
# 3260
# 3261
# no face found !!!
# 3262
# no face found !!!
# 3263
# no face found !!!
# 3264
# no face found !!!
# 3265
# no face found !!!
# 3266
# no face found !!!
# 3267
# no face found !!!
# 3268
# no face found !!!
# 3269
# no face found !!!
# 3270
# no face found !!!
# 3271
# no face found !!!
# 3272
# no face found !!!
# 3273
# no face found !!!
# 3274
# 3275
# no face found !!!
# 3276
# no face found !!!
# 3277
# no face found !!!
# 3278
# no face found !!!
# 3279
# no face found !!!
# 3280
# no face found !!!
# 3281
# no face found !!!
# 3282
# 3283
# 3284
# no face found !!!
# 3285
# 3286
# 3287
# no face found !!!
# 3288
# no face found !!!
# 3289
# 3290
# 3291
# 3292
# no face found !!!
# 3293
# 3294
# 3295
# 3296
# no face found !!!
# 3297
# no face found !!!
# 3298
# no face found !!!
# 3299
# no face found !!!
# 3300
# 3301
# no face found !!!
# 3302
# no face found !!!
# 3303
# 3304
# no face found !!!
# 3305
# no face found !!!
# 3306
# 3307
# no face found !!!
# 3308
# 3309
# 3310
# 3311
# 3312
# no face found !!!
# 3313
# 3314
# no face found !!!
# 3315
# no face found !!!
# 3316
# 3317
# 3318
# no face found !!!
# 3319
# no face found !!!
# 3320
# no face found !!!
# 3321
# no face found !!!
# 3322
# no face found !!!
# 3323
# no face found !!!
# 3324
# no face found !!!
# 3325
# no face found !!!
# 3326
# no face found !!!
# 3327
# 3328
# 3329
# no face found !!!
# 3330
# no face found !!!
# 3331
# no face found !!!
# 3332
# no face found !!!
# 3333
# no face found !!!
# 3334
# no face found !!!
# 3335
# no face found !!!
# 3336
# 3337
# 3338
# 3339
# no face found !!!
# 3340
# 3341
# no face found !!!
# 3342
# no face found !!!
# 3343
# 3344
# 3345
# no face found !!!
# 3346
# no face found !!!
# 3347
# no face found !!!
# 3348
# no face found !!!
# 3349
# no face found !!!
# 3350
# no face found !!!
# 3351
# no face found !!!
# 3352
# no face found !!!
# 3353
# 3354
# no face found !!!
# 3355
# 3356
# no face found !!!
# 3357
# no face found !!!
# 3358
# no face found !!!
# 3359
# no face found !!!
# 3360
# 3361
# no face found !!!
# 3362
# no face found !!!
# 3363
# no face found !!!
# 3364
# no face found !!!
# 3365
# 3366
# 3367
# no face found !!!
# 3368
# 3369
# no face found !!!
# 3370
# 3371
# no face found !!!
# 3372
# 3373
# 3374
# 3375
# no face found !!!
# 3376
# no face found !!!
# 3377
# no face found !!!
# 3378
# 3379
# 3380
# 3381
# no face found !!!
# 3382
# 3383
# 3384
# 3385
# no face found !!!
# 3386
# 3387
# 3388
# no face found !!!
# 3389
# 3390
# 3391
# no face found !!!
# 3392
# no face found !!!
# 3393
# no face found !!!
# 3394
# 3395
# 3396
# 3397
# no face found !!!
# 3398
# no face found !!!
# 3399
# 3400
# 3401
# 3402
# no face found !!!
# 3403
# no face found !!!
# 3404
# no face found !!!
# 3405
# no face found !!!
# 3406
# no face found !!!
# 3407
# 3408
# no face found !!!
# 3409
# no face found !!!
# 3410
# no face found !!!
# 3411
# no face found !!!
# 3412
# 3413
# no face found !!!
# 3414
# no face found !!!
# 3415
# no face found !!!
# 3416
# no face found !!!
# 3417
# 3418
# no face found !!!
# 3419
# no face found !!!
# 3420
# 3421
# 3422
# no face found !!!
# 3423
# no face found !!!
# 3424
# no face found !!!
# 3425
# no face found !!!
# 3426
# no face found !!!
# 3427
# no face found !!!
# 3428
# no face found !!!
# 3429
# 3430
# no face found !!!
# 3431
# no face found !!!
# 3432
# no face found !!!
# 3433
# no face found !!!
# 3434
# 3435
# no face found !!!
# 3436
# no face found !!!
# 3437
# no face found !!!
# 3438
# no face found !!!
# 3439
# no face found !!!
# 3440
# 3441
# no face found !!!
# 3442
# no face found !!!
# 3443
# 3444
# no face found !!!
# 3445
# no face found !!!
# 3446
# no face found !!!
# 3447
# no face found !!!
# 3448
# no face found !!!
# 3449
# no face found !!!
# 3450
# no face found !!!
# 3451
# 3452
# 3453
# no face found !!!
# 3454
# no face found !!!
# 3455
# no face found !!!
# 3456
# no face found !!!
# 3457
# no face found !!!
# 3458
# no face found !!!
# 3459
# no face found !!!
# 3460
# no face found !!!
# 3461
# no face found !!!
# 3462
# 3463
# 3464
# no face found !!!
# 3465
# no face found !!!
# 3466
# 3467
# 3468
# no face found !!!
# 3469
# 3470
# no face found !!!
# 3471
# no face found !!!
# 3472
# 3473
# 3474
# no face found !!!
# 3475
# 3476
# no face found !!!
# 3477
# 3478
# no face found !!!
# 3479
# 3480
# no face found !!!
# 3481
# 3482
# 3483
# no face found !!!
# 3484
# 3485
# no face found !!!
# 3486
# 3487
# no face found !!!
# 3488
# 3489
# 3490
# 3491
# no face found !!!
# 3492
# 3493
# 3494
# no face found !!!
# 3495
# no face found !!!
# 3496
# 3497
# 3498
# 3499
# no face found !!!
# 3500
# no face found !!!
# 3501
# 3502
# 3503
# 3504
# 3505
# no face found !!!
# 3506
# no face found !!!
# 3507
# no face found !!!
# 3508
# 3509
# no face found !!!
# 3510
# 3511
# no face found !!!
# 3512
# no face found !!!
# 3513
# 3514
# no face found !!!
# 3515
# no face found !!!
# 3516
# 3517
# no face found !!!
# 3518
# 3519
# no face found !!!
# 3520
# 3521
# 3522
# 3523
# 3524
# 3525
# 3526
# 3527
# 3528
# 3529
# 3530
# 3531
# no face found !!!
# 3532
# no face found !!!
# 3533
# no face found !!!
# 3534
# no face found !!!
# 3535
# 3536
# 3537
# 3538
# no face found !!!
# 3539
# no face found !!!
# 3540
# 3541
# no face found !!!
# 3542
# 3543
# no face found !!!
# 3544
# no face found !!!
# 3545
# 3546
# 3547
# 3548
# 3549
# 3550
# no face found !!!
# 3551
# 3552
# 3553
# no face found !!!
# 3554
# no face found !!!
# 3555
# no face found !!!
# 3556
# 3557
# 3558
# 3559
# 3560
# no face found !!!
# 3561
# no face found !!!
# 3562
# 3563
# no face found !!!
# 3564
# 3565
# 3566
# 3567
# 3568
# no face found !!!
# 3569
# 3570
# no face found !!!
# 3571
# no face found !!!
# 3572
# no face found !!!
# 3573
# no face found !!!
# 3574
# no face found !!!
# 3575
# 3576
# no face found !!!
# 3577
# no face found !!!
# 3578
# 3579
# 3580
# no face found !!!
# 3581
# 3582
# 3583
# 3584
# 3585
# 3586
# no face found !!!
# 3587
# no face found !!!
# 3588
# no face found !!!
# 3589
# 3590
# no face found !!!
# 3591
# 3592
# no face found !!!
# 3593
# 3594
# 3595
# no face found !!!
# 3596
# no face found !!!
# 3597
# no face found !!!
# 3598
# no face found !!!
# 3599
# no face found !!!
# 3600
# 3601
# 3602
# 3603
# no face found !!!
# 3604
# no face found !!!
# 3605
# no face found !!!
# 3606
# no face found !!!
# 3607
# no face found !!!
# 3608
# no face found !!!
# 3609
# no face found !!!
# 3610
# no face found !!!
# 3611
# 3612
# no face found !!!
# 3613
# 3614
# no face found !!!
# 3615
# no face found !!!
# 3616
# no face found !!!
# 3617
# 3618
# 3619
# 3620
# 3621
# no face found !!!
# 3622
# 3623
# 3624
# 3625
# 3626
# no face found !!!
# 3627
# 3628
# no face found !!!
# 3629
# 3630
# no face found !!!
# 3631
# no face found !!!
# 3632
# 3633
# 3634
# no face found !!!
# 3635
# 3636
# 3637
# 3638
# no face found !!!
# 3639
# 3640
# no face found !!!
# 3641
# 3642
# no face found !!!
# 3643
# no face found !!!
# 3644
# no face found !!!
# 3645
# no face found !!!
# 3646
# no face found !!!
# 3647
# no face found !!!
# 3648
# 3649
# 3650
# 3651
# 3652
# no face found !!!
# 3653
# 3654
# 3655
# 3656
# no face found !!!
# 3657
# no face found !!!
# 3658
# 3659
# 3660
# no face found !!!
# 3661
# 3662
# 3663
# no face found !!!
# 3664
# 3665
# 3666
# 3667
# 3668
# no face found !!!
# 3669
# 3670
# 3671
# 3672
# 3673
# 3674
# no face found !!!
# 3675
# 3676
# 3677
# 3678
# 3679
# no face found !!!
# 3680
# no face found !!!
# 3681
# no face found !!!
# 3682
# no face found !!!
# 3683
# 3684
# 3685
# no face found !!!
# 3686
# no face found !!!
# 3687
# 3688
# no face found !!!
# 3689
# 3690
# 3691
# no face found !!!
# 3692
# no face found !!!
# 3693
# 3694
# 3695
# 3696
# no face found !!!
# 3697
# no face found !!!
# 3698
# 3699
# 3700
# no face found !!!
# 3701
# 3702
# no face found !!!
# 3703
# no face found !!!
# 3704
# no face found !!!
# 3705
# 3706
# 3707
# 3708
# 3709
# no face found !!!
# 3710
# 3711
# no face found !!!
# 3712
# 3713
# no face found !!!
# 3714
# 3715
# 3716
# no face found !!!
# 3717
# no face found !!!
# 3718
# 3719
# 3720
# no face found !!!
# 3721
# no face found !!!
# 3722
# no face found !!!
# 3723
# 3724
# 3725
# 3726
# no face found !!!
# 3727
# 3728
# no face found !!!
# 3729
# no face found !!!
# 3730
# no face found !!!
# 3731
# 3732
# 3733
# 3734
# 3735
# no face found !!!
# 3736
# 3737
# no face found !!!
# 3738
# 3739
# 3740
# 3741
# no face found !!!
# 3742
# 3743
# no face found !!!
# 3744
# 3745
# 3746
# no face found !!!
# 3747
# no face found !!!
# 3748
# no face found !!!
# 3749
# no face found !!!
# 3750
# 3751
# 3752
# 3753
# no face found !!!
# 3754
# 3755
# no face found !!!
# 3756
# 3757
# 3758
# no face found !!!
# 3759
# no face found !!!
# 3760
# 3761
# 3762
# 3763
# 3764
# 3765
# no face found !!!
# 3766
# no face found !!!
# 3767
# no face found !!!
# 3768
# 3769
# 3770
# no face found !!!
# 3771
# 3772
# 3773
# 3774
# 3775
# no face found !!!
# 3776
# no face found !!!
# 3777
# no face found !!!
# 3778
# no face found !!!
# 3779
# 3780
# no face found !!!
# 3781
# 3782
# no face found !!!
# 3783
# 3784
# no face found !!!
# 3785
# 3786
# 3787
# no face found !!!
# 3788
# 3789
# 3790
# 3791
# no face found !!!
# 3792
# 3793
# 3794
# no face found !!!
# 3795
# no face found !!!
# 3796
# 3797
# 3798
# no face found !!!
# 3799
# 3800
# 3801
# 3802
# no face found !!!
# 3803
# no face found !!!
# 3804
# no face found !!!
# 3805
# no face found !!!
# 3806
# no face found !!!
# 3807
# no face found !!!
# 3808
# 3809
# no face found !!!
# 3810
# no face found !!!
# 3811
# 3812
# no face found !!!
# 3813
# no face found !!!
# 3814
# no face found !!!
# 3815
# 3816
# 3817
# 3818
# no face found !!!
# 3819
# no face found !!!
# 3820
# 3821
# 3822
# no face found !!!
# 3823
# 3824
# no face found !!!
# 3825
# no face found !!!
# 3826
# no face found !!!
# 3827
# no face found !!!
# 3828
# 3829
# 3830
# no face found !!!
# 3831
# no face found !!!
# 3832
# no face found !!!
# 3833
# 3834
# 3835
# no face found !!!
# 3836
# 3837
# no face found !!!
# 3838
# no face found !!!
# 3839
# no face found !!!
# 3840
# 3841
# 3842
# no face found !!!
# 3843
# 3844
# no face found !!!
# 3845
# no face found !!!
# 3846
# 3847
# 3848
# 3849
# no face found !!!
# 3850
# no face found !!!
# 3851
# no face found !!!
# 3852
# 3853
# no face found !!!
# 3854
# no face found !!!
# 3855
# 3856
# no face found !!!
# 3857
# 3858
# 3859
# 3860
# 3861
# no face found !!!
# 3862
# 3863
# no face found !!!
# 3864
# 3865
# 3866
# no face found !!!
# 3867
# 3868
# 3869
# no face found !!!
# 3870
# 3871
# no face found !!!
# 3872
# no face found !!!
# 3873
# 3874
# 3875
# 3876
# no face found !!!
# 3877
# no face found !!!
# 3878
# no face found !!!
# 3879
# 3880
# 3881
# no face found !!!
# 3882
# no face found !!!
# 3883
# no face found !!!
# 3884
# no face found !!!
# 3885
# no face found !!!
# 3886
# 3887
# no face found !!!
# 3888
# no face found !!!
# 3889
# no face found !!!
# 3890
# no face found !!!
# 3891
# no face found !!!
# 3892
# no face found !!!
# 3893
# no face found !!!
# 3894
# no face found !!!
# 3895
# no face found !!!
# 3896
# 3897
# no face found !!!
# 3898
# no face found !!!
# 3899
# no face found !!!
# 3900
# 3901
# no face found !!!
# 3902
# 3903
# no face found !!!
# 3904
# 3905
# no face found !!!
# 3906
# 3907
# no face found !!!
# 3908
# no face found !!!
# 3909
# no face found !!!
# 3910
# 3911
# 3912
# 3913
# no face found !!!
# 3914
# 3915
# 3916
# 3917
# 3918
# 3919
# 3920
# 3921
# 3922
# 3923
# no face found !!!
# 3924
# 3925
# 3926
# 3927
# 3928
# 3929
# 3930
# no face found !!!
# 3931
# 3932
# 3933
# 3934
# no face found !!!
# 3935
# 3936
# 3937
# no face found !!!
# 3938
# no face found !!!
# 3939
# no face found !!!
# 3940
# no face found !!!
# 3941
# no face found !!!
# 3942
# no face found !!!
# 3943
# 3944
# no face found !!!
# 3945
# no face found !!!
# 3946
# 3947
# no face found !!!
# 3948
# 3949
# no face found !!!
# 3950
# no face found !!!
# 3951
# 3952
# no face found !!!
# 3953
# 3954
# 3955
# no face found !!!
# 3956
# no face found !!!
# 3957
# no face found !!!
# 3958
# 3959
# no face found !!!
# 3960
# no face found !!!
# 3961
# no face found !!!
# 3962
# 3963
# 3964
# 3965
# 3966
# 3967
# 3968
# 3969
# 3970
# 3971
# 3972
# 3973
# 3974
# 3975
# 3976
# 3977
# 3978
# 3979
# 3980
# 3981
# 3982
# 3983
# no face found !!!
# 3984
# 3985
# 3986
# no face found !!!
# 3987
# no face found !!!
# 3988
# 3989
# 3990
# no face found !!!
# 3991
# no face found !!!
# 3992
# no face found !!!
# 3993
# no face found !!!
# 3994
# 3995
# no face found !!!
# 3996
# no face found !!!
# 3997
# 3998
# no face found !!!
# 3999
# no face found !!!
# 4000
# 4001
# no face found !!!
# 4002
# 4003
# 4004
# no face found !!!
# 4005
# no face found !!!
# 4006
# no face found !!!
# 4007
# 4008
# no face found !!!
# 4009
# no face found !!!
# 4010
# 4011
# no face found !!!
# 4012
# no face found !!!
# 4013
# 4014
# no face found !!!
# 4015
# no face found !!!
# 4016
# no face found !!!
# 4017
# no face found !!!
# 4018
# no face found !!!
# 4019
# no face found !!!
# 4020
# no face found !!!
# 4021
# no face found !!!
# 4022
# 4023
# no face found !!!
# 4024
# no face found !!!
# 4025
# 4026
# 4027
# 4028
# 4029
# 4030
# no face found !!!
# 4031
# no face found !!!
# 4032
# 4033
# 4034
# 4035
# no face found !!!
# 4036
# no face found !!!
# 4037
# no face found !!!
# 4038
# 4039
# no face found !!!
# 4040
# 4041
# 4042
# no face found !!!
# 4043
# 4044
# 4045
# 4046
# 4047
# no face found !!!
# 4048
# no face found !!!
# 4049
# 4050
# no face found !!!
# 4051
# 4052
# 4053
# 4054
# no face found !!!
# 4055
# 4056
# 4057
# 4058
# no face found !!!
# 4059
# 4060
# 4061
# no face found !!!
# 4062
# 4063
# no face found !!!
# 4064
# no face found !!!
# 4065
# 4066
# 4067
# 4068
# no face found !!!
# 4069
# no face found !!!
# 4070
# 4071
# 4072
# 4073
# no face found !!!
# 4074
# 4075
# no face found !!!
# 4076
# 4077
# 4078
# 4079
# 4080
# 4081
# 4082
# no face found !!!
# 4083
# no face found !!!
# 4084
# 4085
# no face found !!!
# 4086
# no face found !!!
# 4087
# 4088
# no face found !!!
# 4089
# no face found !!!
# 4090
# no face found !!!
# 4091
# no face found !!!
# 4092
# no face found !!!
# 4093
# no face found !!!
# 4094
# no face found !!!
# 4095
# no face found !!!
# 4096
# no face found !!!
# 4097
# 4098
# no face found !!!
# 4099
# 4100
# no face found !!!
# 4101
# 4102
# no face found !!!
# 4103
# no face found !!!
# 4104
# no face found !!!
# 4105
# no face found !!!
# 4106
# no face found !!!
# 4107
# no face found !!!
# 4108
# no face found !!!
# 4109
# no face found !!!
# 4110
# no face found !!!
# 4111
# no face found !!!
# 4112
# no face found !!!
# 4113
# 4114
# no face found !!!
# 4115
# 4116
# no face found !!!
# 4117
# no face found !!!
# 4118
# no face found !!!
# 4119
# no face found !!!
# 4120
# 4121
# 4122
# 4123
# no face found !!!
# 4124
# no face found !!!
# 4125
# 4126
# no face found !!!
# 4127
# 4128
# no face found !!!
# 4129
# no face found !!!
# 4130
# no face found !!!
# 4131
# 4132
# no face found !!!
# 4133
# no face found !!!
# 4134
# no face found !!!
# 4135
# no face found !!!
# 4136
# no face found !!!
# 4137
# 4138
# no face found !!!
# 4139
# no face found !!!
# 4140
# no face found !!!
# 4141
# no face found !!!
# 4142
# no face found !!!
# 4143
# no face found !!!
# 4144
# no face found !!!
# 4145
# no face found !!!
# 4146
# no face found !!!
# 4147
# no face found !!!
# 4148
# 4149
# 4150
# no face found !!!
# 4151
# no face found !!!
# 4152
# no face found !!!
# 4153
# no face found !!!
# 4154
# no face found !!!
# 4155
# 4156
# no face found !!!
# 4157
# no face found !!!
# 4158
# no face found !!!
# 4159
# no face found !!!
# 4160
# 4161
# 4162
# 4163
# 4164
# no face found !!!
# 4165
# no face found !!!
# 4166
# no face found !!!
# 4167
# 4168
# no face found !!!
# 4169
# 4170
# 4171
# 4172
# no face found !!!
# 4173
# no face found !!!
# 4174
# no face found !!!
# 4175
# no face found !!!
# 4176
# no face found !!!
# 4177
# no face found !!!
# 4178
# 4179
# no face found !!!
# 4180
# no face found !!!
# 4181
# no face found !!!
# 4182
# no face found !!!
# 4183
# no face found !!!
# 4184
# no face found !!!
# 4185
# 4186
# no face found !!!
# 4187
# 4188
# no face found !!!
# 4189
# 4190
# no face found !!!
# 4191
# 4192
# 4193
# 4194
# no face found !!!
# 4195
# 4196
# no face found !!!
# 4197
# 4198
# no face found !!!
# 4199
# no face found !!!
# 4200
# no face found !!!
# 4201
# 4202
# no face found !!!
# 4203
# no face found !!!
# 4204
# 4205
# 4206
# 4207
# 4208
# no face found !!!
# 4209
# no face found !!!
# 4210
# no face found !!!
# 4211
# no face found !!!
# 4212
# no face found !!!
# 4213
# no face found !!!
# 4214
# no face found !!!
# 4215
# 4216
# no face found !!!
# 4217
# 4218
# no face found !!!
# 4219
# no face found !!!
# 4220
# no face found !!!
# 4221
# no face found !!!
# 4222
# no face found !!!
# 4223
# no face found !!!
# 4224
# no face found !!!
# 4225
# no face found !!!
# 4226
# 4227
# no face found !!!
# 4228
# no face found !!!
# 4229
# 4230
# no face found !!!
# 4231
# no face found !!!
# 4232
# no face found !!!
# 4233
# no face found !!!
# 4234
# no face found !!!
# 4235
# no face found !!!
# 4236
# no face found !!!
# 4237
# no face found !!!
# 4238
# no face found !!!
# 4239
# no face found !!!
# 4240
# 4241
# no face found !!!
# 4242
# no face found !!!
# 4243
# no face found !!!
# 4244
# no face found !!!
# 4245
# no face found !!!
# 4246
# 4247
# 4248
# no face found !!!
# 4249
# no face found !!!
# 4250
# no face found !!!
# 4251
# no face found !!!
# 4252
# no face found !!!
# 4253
# 4254
# 4255
# no face found !!!
# 4256
# 4257
# no face found !!!
# 4258
# no face found !!!
# 4259
# no face found !!!
# 4260
# 4261
# no face found !!!
# 4262
# no face found !!!
# 4263
# 4264
# 4265
# 4266
# no face found !!!
# 4267
# no face found !!!
# 4268
# no face found !!!
# 4269
# no face found !!!
# 4270
# no face found !!!
# 4271
# 4272
# no face found !!!
# 4273
# no face found !!!
# 4274
# no face found !!!
# 4275
# no face found !!!
# 4276
# no face found !!!
# 4277
# no face found !!!
# 4278
# no face found !!!
# 4279
# no face found !!!
# 4280
# no face found !!!
# 4281
# no face found !!!
# 4282
# no face found !!!
# 4283
# no face found !!!
# 4284
# no face found !!!
# 4285
# no face found !!!
# 4286
# no face found !!!
# 4287
# no face found !!!
# 4288
# no face found !!!
# 4289
# 4290
# no face found !!!
# 4291
# 4292
# no face found !!!
# 4293
# no face found !!!
# 4294
# no face found !!!
# 4295
# no face found !!!
# 4296
# no face found !!!
# 4297
# no face found !!!
# 4298
# no face found !!!
# 4299

# %%
bmi_final
# Out:
#       height     weight        bmi  \
# 1   1.727629  74.292506  24.891107
# 1   1.662531  63.426103  22.947145
# 1   1.627693  62.209449  23.480723
# 1   1.653157  57.366289  20.990779
# 1   1.727629  74.292506  24.891107
# ..       ...        ...        ...
# 1   1.727629  74.292506  24.891107
# 1   1.730742  75.555137  25.223163
# 1   1.727629  74.292506  24.891107
# 1   1.741627  59.333607  19.560975
# 1   1.639168  58.158433    21.6454
#
#                                                   url
# 1   https://scontent-lga3-2.cdninstagram.com/v/t51...
# 1   https://scontent-lga3-2.cdninstagram.com/v/t51...
# 1   https://scontent-lga3-2.cdninstagram.com/v/t51...
# 1   https://scontent-lga3-2.cdninstagram.com/v/t51...
# 1   https://scontent-lga3-2.cdninstagram.com/v/t51...
# ..                                                ...
# 1   https://scontent-lga3-2.cdninstagram.com/v/t51...
# 1   https://scontent-lga3-2.cdninstagram.com/v/t51...
# 1   https://scontent-lga3-2.cdninstagram.com/v/t51...
# 1   https://scontent-lga3-2.cdninstagram.com/v/t51...
# 1   https://scontent-lga3-2.cdninstagram.com/v/t51...
#
# [5054 rows x 4 columns]

# %%
final = pd.merge(image_links,bmi_final,how = "left",left_on="links",right_on="url")

# %%
final = final.dropna()

# %%
final.dtypes
# Out:
# name            object
# lat            float64
# lng            float64
# links           object
# external_id      int64
# state           object
# bmi             object
# dtype: object

# %%
final['bmi'] = final['bmi'].astype(str)
a = ['24.891107004056106']
final = final[~final['bmi'].isin(a)]

# %%
final = final.drop(['height','weight','url'],axis=1)

# %%
final
# Out:
#                                    name        lat        lng  \
# 1                      Ashton, Maryland  39.153560 -77.003750
# 2                      Ashton, Maryland  39.153560 -77.003750
# 3                      Ashton, Maryland  39.153560 -77.003750
# 9                      Ashton, Maryland  39.153560 -77.003750
# 10                     Ashton, Maryland  39.153560 -77.003750
# ...                                 ...        ...        ...
# 5168  Aerospace Museum of Washington Dc  38.303732 -76.525004
# 5169  Aerospace Museum of Washington Dc  38.303732 -76.525004
# 5172  Aerospace Museum of Washington Dc  38.303732 -76.525004
# 5174  Aerospace Museum of Washington Dc  38.303732 -76.525004
# 5175  Aerospace Museum of Washington Dc  38.303732 -76.525004
#
#                                                   links      external_id  \
# 1     https://scontent-lga3-2.cdninstagram.com/v/t51...  112777142067835
# 2     https://scontent-lga3-2.cdninstagram.com/v/t51...  112777142067835
# 3     https://scontent-lga3-2.cdninstagram.com/v/t51...  112777142067835
# 9     https://scontent-lga3-2.cdninstagram.com/v/t51...  112777142067835
# 10    https://scontent-lga3-2.cdninstagram.com/v/t51...  112777142067835
# ...                                                 ...              ...
# 5168  https://scontent-lga3-2.cdninstagram.com/v/t51...  587309104707565
# 5169  https://scontent-lga3-2.cdninstagram.com/v/t51...  587309104707565
# 5172  https://scontent-lga3-2.cdninstagram.com/v/t51...  587309104707565
# 5174  https://scontent-lga3-2.cdninstagram.com/v/t51...  587309104707565
# 5175  https://scontent-lga3-2.cdninstagram.com/v/t51...  587309104707565
#
#          state                 bmi
# 1     Maryland  22.947144661995605
# 2     Maryland   23.48072282836675
# 3     Maryland  20.990779442950867
# 9     Maryland   23.13673661990269
# 10    Maryland   22.50025834514273
# ...        ...                 ...
# 5168  Maryland  24.270045072455545
# 5169  Maryland   22.59530458038064
# 5172  Maryland  25.223163250122255
# 5174  Maryland   19.56097522595658
# 5175  Maryland  21.645399664594507
#
# [2383 rows x 7 columns]

# %%
final.rename(columns={'lng':'long'},inplace=True)

# %%
import datetime

from google.cloud import bigquery
import pandas
import pytz

# Construct a BigQuery client object.
client = bigquery.Client()

# TODO(developer): Set table_id to the ID of the table to create.
table_id = "columbia-obesity.model.model_bmi"

job_config = bigquery.LoadJobConfig(
    # Specify a (partial) schema. All columns are always written to the
    # table. The schema is used to assist in data type definitions.
    schema=[
        # Specify the type of columns whose type cannot be auto-detected. For
        # example the "title" column uses pandas dtype "object", so its
        # data type is ambiguous.
        bigquery.SchemaField("name", bigquery.enums.SqlTypeNames.STRING),
        # Indexes are written if included in the schema by name.
        bigquery.SchemaField("lat", bigquery.enums.SqlTypeNames.FLOAT64),
        bigquery.SchemaField("long", bigquery.enums.SqlTypeNames.FLOAT64),
        bigquery.SchemaField("links", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("external_id", bigquery.enums.SqlTypeNames.INTEGER),
        bigquery.SchemaField("state", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("bmi", bigquery.enums.SqlTypeNames.STRING)
    ],
    # Optionally, set the write disposition. BigQuery appends loaded rows
    # to an existing table by default, but with WRITE_TRUNCATE write
    # disposition it replaces the table with the loaded data.
    write_disposition="WRITE_TRUNCATE",
)

job = client.load_table_from_dataframe(
    final, table_id, job_config=job_config
)  # Make an API request.
job.result()  # Wait for the job to complete.

table = client.get_table(table_id)  # Make an API request.
print(
    "Loaded {} rows and {} columns to {}".format(
        table.num_rows, len(table.schema), table_id
    )
)
# Out:
# Loaded 2383 rows and 7 columns to columbia-obesity.model.model_bmi

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Face is almost able to predict BMI correctly. There are places where it is going wrong for example if you predict heigt of really tall celebrity like rampal.
# This behavior is acceptable since we have not trained the model on such tall celebrities. Other,issue that i noticed is the face to weight tagging is not that much appropriate since the faces are from diffrent times but the weight is always the latest.
# We can get even better model if we have these mappings right.
#
# Also we can improve on height prediction if we model the torso alongwith the face. However , we need to get torso to correct height labeled data for this. In the absence of such data we can rely on the face as height estimator.
